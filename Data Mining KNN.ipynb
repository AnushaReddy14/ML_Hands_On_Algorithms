# %% [markdown]
# # Diabetes Prediction Using k Nearest Neighbors

# %%
import pandas as pd
import numpy as np

# %%
from pandas import read_csv
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier

# %%
df = read_csv("diabetes.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.shape
# Out:
# (768, 9)

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
df1=df.copy()

# %%
# Zero not acceppted features - replace zeros with mean of the respective columns
z_n_a = ['Glucose','BloodPressure','SkinThickness','Insulin','BMI']
for column in z_n_a:
    df1[column] = df1[column].replace(0,np.NaN)
    mean = int(df1[column].mean(skipna=True))
    df1[column] = df1[column].replace(np.NaN,mean)

# %%
array = df.values
X = array[:,0:8]
y = array[:,8]

# %%
def func1():
    k_range = range(1, 10)
    n_range = range(2,10)
    kscores = []
    nsplits = []
    f_results = 0
    f_k = 0
    f_ns = 0
    result_l = []
    for n in n_range:
        for k in k_range:
            kfold = KFold(n_splits=n, random_state=2, shuffle=True)
            knn = KNeighborsClassifier(n_neighbors=k)
            results = cross_val_score(knn, X, y, cv = kfold)
            if(results.mean() > f_results):
                f_k = k
                f_ns = n
                f_results = results.mean()
                result_l.append(results.mean())
                nsplits.append(n)
                kscores.append(k)
    print('k = ',f_k,' n_splits = ',f_ns,' result = ',f_results)
    print()

# %%
func1()
# Out:
# k =  9  n_splits =  8  result =  0.74609375

# %% [markdown]
# Import Library

# %%
import pandas as pd
import numpy as np

from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import GridSearchCV

import warnings
warnings.filterwarnings('ignore')

# %%
df_model = df.copy()

features = list(df_model.columns)
features = [features[:-1]]
print(features)
# Out:
# [['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']]

# %% [markdown]
# Scaling with MinMaxScaler

# %%
scaler = MinMaxScaler()
for feature in features:
    df_model[feature] = scaler.fit_transform(df_model[feature])

#Create KNN Object
knn = KNeighborsClassifier()

#Create X and y variable
X = df_model.drop(columns=['Outcome'])
y = df_model['Outcome']

func1()
# Out:
# k =  7  n_splits =  8  result =  0.7447916666666666

# %% [markdown]
# Scaling with Robust Scaler

# %%
df_model = df.copy()

features = list(df_model.columns)
features = [features[:-1]]
#print(features)

scaler = RobustScaler()
for feature in features:
    df_model[feature] = scaler.fit_transform(df_model[feature])

#Create KNN Object
knn = KNeighborsClassifier()

#Create X and y variable
X = df_model.drop(columns=['Outcome'])
y = df_model['Outcome']

func1()
# Out:
# k =  5  n_splits =  3  result =  0.7630208333333334

# %% [markdown]
# Modeling with Standard Scaler

# %%
df_model = df.copy()

#list(df_model.columns.values.tolist())
#list(df_model.columns.values)
features = list(df_model.columns)
#print(features)
features = [features[:-1]]

#for feature in features:
#    print(feature)

scaler = StandardScaler()

for feature in features:
    df_model[feature] = scaler.fit_transform(df_model[feature])

#Create KNN Object
knn = KNeighborsClassifier()

#Create X and y variable
X = df_model.drop(columns=['Outcome'])
y = df_model['Outcome']

func1()
# Out:
# k =  5  n_splits =  3  result =  0.7526041666666666

# %% [markdown]
# # Feature Selection and Feature Scaling

# %%
l = []
for i in range(1,9):
    for j in range(1,9):
        l.append([i,j])

# %% [markdown]
# # Modeling with RobustScaler

# %%
#RobustScaler
# Removing 1 Feature and Selecting 7 other features
features = list(df1.columns)
features = [features[:-1]]

scaler = RobustScaler()
for feature in features:
    df1[feature] = scaler.fit_transform(df1[feature])


#Create X and y variable
for feature in features[0]: 
    print(feature)
    X = df1.drop(columns=['Outcome',feature])
    y = df1['Outcome']
    func1()
# Out:
# Pregnancies
# k =  7  n_splits =  3  result =  0.7565104166666666
#
# Glucose
# k =  9  n_splits =  9  result =  0.6823985408116735
#
# BloodPressure
# k =  9  n_splits =  6  result =  0.7526041666666666
#
# SkinThickness
# k =  8  n_splits =  6  result =  0.7526041666666666
#
# Insulin
# k =  9  n_splits =  3  result =  0.74609375
#
# BMI
# k =  7  n_splits =  3  result =  0.7369791666666666
#
# DiabetesPedigreeFunction
# k =  7  n_splits =  3  result =  0.7708333333333334
#
# Age
# k =  9  n_splits =  3  result =  0.7369791666666666

# %%
#RobustScaler
# Removal of 2 features selecting 6 other 
features = list(df1.columns)
features = [features[:-1]]

scaler = RobustScaler()
for feature in features:
    df1[feature] = scaler.fit_transform(df1[feature])

l = []
for i in range(0,8):
    for j in range(i+1,8):
        l.append([i,j])


#Create X and y variable
for i in l: 
    print(features[0][i[0]],features[0][i[1]])
    X = df1.drop(columns=['Outcome', features[0][i[0]],features[0][i[1]]])
    y = df1['Outcome']
    func1()
# Out:
# Pregnancies Glucose
# k =  9  n_splits =  9  result =  0.7122663018695851
#
# Pregnancies BloodPressure
# k =  7  n_splits =  2  result =  0.7552083333333333
#
# Pregnancies SkinThickness
# k =  9  n_splits =  2  result =  0.76171875
#
# Pregnancies Insulin
# k =  9  n_splits =  3  result =  0.7473958333333334
#
# Pregnancies BMI
# k =  7  n_splits =  3  result =  0.73046875
#
# Pregnancies DiabetesPedigreeFunction
# k =  9  n_splits =  3  result =  0.76953125
#
# Pregnancies Age
# k =  9  n_splits =  3  result =  0.75
#
# Glucose BloodPressure
# k =  9  n_splits =  8  result =  0.6940104166666666
#
# Glucose SkinThickness
# k =  9  n_splits =  3  result =  0.69921875
#
# Glucose Insulin
# k =  9  n_splits =  2  result =  0.6666666666666666
#
# Glucose BMI
# k =  9  n_splits =  3  result =  0.67578125
#
# Glucose DiabetesPedigreeFunction
# k =  7  n_splits =  6  result =  0.68359375
#
# Glucose Age
# k =  9  n_splits =  9  result =  0.6940112479100168
#
# BloodPressure SkinThickness
# k =  9  n_splits =  4  result =  0.7552083333333334
#
# BloodPressure Insulin
# k =  9  n_splits =  4  result =  0.7473958333333334
#
# BloodPressure BMI
# k =  9  n_splits =  3  result =  0.7369791666666666
#
# BloodPressure DiabetesPedigreeFunction
# k =  9  n_splits =  3  result =  0.75390625
#
# BloodPressure Age
# k =  9  n_splits =  2  result =  0.734375
#
# SkinThickness Insulin
# k =  9  n_splits =  4  result =  0.7617187500000001
#
# SkinThickness BMI
# k =  7  n_splits =  9  result =  0.7487156102751178
#
# SkinThickness DiabetesPedigreeFunction
# k =  7  n_splits =  3  result =  0.7578125
#
# SkinThickness Age
# k =  9  n_splits =  3  result =  0.7513020833333334
#
# Insulin BMI
# k =  8  n_splits =  2  result =  0.72265625
#
# Insulin DiabetesPedigreeFunction
# k =  7  n_splits =  3  result =  0.7526041666666666
#
# Insulin Age
# k =  8  n_splits =  3  result =  0.7252604166666666
#
# BMI DiabetesPedigreeFunction
# k =  7  n_splits =  5  result =  0.738349885408709
#
# BMI Age
# k =  9  n_splits =  6  result =  0.7317708333333334
#
# DiabetesPedigreeFunction Age
# k =  9  n_splits =  6  result =  0.7473958333333334

# %%
#RobustScaler
# Removal of 3 features 
features = list(df1.columns)
features = [features[:-1]]

scaler = RobustScaler()
for feature in features:
    df1[feature] = scaler.fit_transform(df1[feature])

l = []
for i in range(0,8):
    for j in range(i+1,8):
        for k in range(j+1,8):
            l.append([i,j,k])


    
#Create X and y variable
for i in l: 
    print(features[0][i[0]],features[0][i[1]],features[0][i[2]])
    X = df1.drop(columns=['Outcome', features[0][i[0]],features[0][i[1]],features[0][i[2]]])
    y = df1['Outcome']
    func1()
# Out:
# Pregnancies Glucose BloodPressure
# k =  7  n_splits =  5  result =  0.6992700110347169
#
# Pregnancies Glucose SkinThickness
# k =  9  n_splits =  9  result =  0.7005319957440341
#
# Pregnancies Glucose Insulin
# k =  9  n_splits =  5  result =  0.6849673202614379
#
# Pregnancies Glucose BMI
# k =  9  n_splits =  8  result =  0.6822916666666666
#
# Pregnancies Glucose DiabetesPedigreeFunction
# k =  9  n_splits =  6  result =  0.6809895833333334
#
# Pregnancies Glucose Age
# k =  9  n_splits =  6  result =  0.7122395833333334
#
# Pregnancies BloodPressure SkinThickness
# k =  7  n_splits =  2  result =  0.77734375
#
# Pregnancies BloodPressure Insulin
# k =  8  n_splits =  2  result =  0.7578125
#
# Pregnancies BloodPressure BMI
# k =  7  n_splits =  6  result =  0.7395833333333334
#
# Pregnancies BloodPressure DiabetesPedigreeFunction
# k =  9  n_splits =  3  result =  0.75390625
#
# Pregnancies BloodPressure Age
# k =  9  n_splits =  3  result =  0.7434895833333334
#
# Pregnancies SkinThickness Insulin
# k =  9  n_splits =  2  result =  0.7682291666666667
#
# Pregnancies SkinThickness BMI
# k =  6  n_splits =  6  result =  0.7526041666666666
#
# Pregnancies SkinThickness DiabetesPedigreeFunction
# k =  8  n_splits =  8  result =  0.7434895833333334
#
# Pregnancies SkinThickness Age
# k =  9  n_splits =  2  result =  0.7473958333333334
#
# Pregnancies Insulin BMI
# k =  9  n_splits =  7  result =  0.742166090789944
#
# Pregnancies Insulin DiabetesPedigreeFunction
# k =  9  n_splits =  5  result =  0.7565571683218743
#
# Pregnancies Insulin Age
# k =  8  n_splits =  3  result =  0.73828125
#
# Pregnancies BMI DiabetesPedigreeFunction
# k =  8  n_splits =  8  result =  0.7434895833333334
#
# Pregnancies BMI Age
# k =  9  n_splits =  6  result =  0.734375
#
# Pregnancies DiabetesPedigreeFunction Age
# k =  9  n_splits =  5  result =  0.7604702487055428
#
# Glucose BloodPressure SkinThickness
# k =  7  n_splits =  4  result =  0.70703125
#
# Glucose BloodPressure Insulin
# k =  9  n_splits =  8  result =  0.66796875
#
# Glucose BloodPressure BMI
# k =  5  n_splits =  4  result =  0.6888020833333334
#
# Glucose BloodPressure DiabetesPedigreeFunction
# k =  5  n_splits =  4  result =  0.6861979166666667
#
# Glucose BloodPressure Age
# k =  5  n_splits =  3  result =  0.6901041666666666
#
# Glucose SkinThickness Insulin
# k =  9  n_splits =  4  result =  0.67578125
#
# Glucose SkinThickness BMI
# k =  9  n_splits =  4  result =  0.68359375
#
# Glucose SkinThickness DiabetesPedigreeFunction
# k =  7  n_splits =  3  result =  0.6861979166666666
#
# Glucose SkinThickness Age
# k =  9  n_splits =  3  result =  0.6809895833333334
#
# Glucose Insulin BMI
# k =  8  n_splits =  9  result =  0.657577139382885
#
# Glucose Insulin DiabetesPedigreeFunction
# k =  9  n_splits =  3  result =  0.6497395833333334
#
# Glucose Insulin Age
# k =  8  n_splits =  3  result =  0.6549479166666666
#
# Glucose BMI DiabetesPedigreeFunction
# k =  9  n_splits =  3  result =  0.6731770833333334
#
# Glucose BMI Age
# k =  9  n_splits =  3  result =  0.66796875
#
# Glucose DiabetesPedigreeFunction Age
# k =  8  n_splits =  6  result =  0.6744791666666666
#
# BloodPressure SkinThickness Insulin
# k =  9  n_splits =  4  result =  0.7643229166666667
#
# BloodPressure SkinThickness BMI
# k =  9  n_splits =  4  result =  0.7486979166666666
#
# BloodPressure SkinThickness DiabetesPedigreeFunction
# k =  9  n_splits =  4  result =  0.7565104166666667
#
# BloodPressure SkinThickness Age
# k =  9  n_splits =  3  result =  0.7473958333333334
#
# BloodPressure Insulin BMI
# k =  9  n_splits =  4  result =  0.72265625
#
# BloodPressure Insulin DiabetesPedigreeFunction
# k =  9  n_splits =  2  result =  0.7447916666666667
#
# BloodPressure Insulin Age
# k =  9  n_splits =  4  result =  0.7421874999999999
#
# BloodPressure BMI DiabetesPedigreeFunction
# k =  9  n_splits =  3  result =  0.7408854166666666
#
# BloodPressure BMI Age
# k =  9  n_splits =  3  result =  0.734375
#
# BloodPressure DiabetesPedigreeFunction Age
# k =  7  n_splits =  5  result =  0.7448179271708684
#
# SkinThickness Insulin BMI
# k =  7  n_splits =  8  result =  0.7447916666666666
#
# SkinThickness Insulin DiabetesPedigreeFunction
# k =  7  n_splits =  7  result =  0.7644227332300727
#
# SkinThickness Insulin Age
# k =  8  n_splits =  3  result =  0.7434895833333334
#
# SkinThickness BMI DiabetesPedigreeFunction
# k =  7  n_splits =  4  result =  0.7395833333333334
#
# SkinThickness BMI Age
# k =  9  n_splits =  3  result =  0.7291666666666666
#
# SkinThickness DiabetesPedigreeFunction Age
# k =  8  n_splits =  8  result =  0.7473958333333333
#
# Insulin BMI DiabetesPedigreeFunction
# k =  9  n_splits =  2  result =  0.7265625
#
# Insulin BMI Age
# k =  7  n_splits =  6  result =  0.7135416666666666
#
# Insulin DiabetesPedigreeFunction Age
# k =  9  n_splits =  9  result =  0.7448396412828697
#
# BMI DiabetesPedigreeFunction Age
# k =  7  n_splits =  5  result =  0.727900857312622

# %%
#RobustScaler
# Removal of 4 features
features = list(df1.columns)
features = [features[:-1]]

scaler = RobustScaler()
for feature in features:
    df1[feature] = scaler.fit_transform(df1[feature])

l = []
for i in range(0,8):
    for j in range(i+1,8):
        for k in range(j+1,8):
            for m in range(k+1,8):
                l.append([i,j,k,m])


    
#Create X and y variable
for i in l: 
    print(features[0][i[0]],features[0][i[1]],features[0][i[2]],features[0][i[3]])
    X = df1.drop(columns=['Outcome', features[0][i[0]],features[0][i[1]],features[0][i[2]],features[0][i[3]]])
    y = df1['Outcome']
    func1()
# Out:
# Pregnancies Glucose BloodPressure SkinThickness
# k =  8  n_splits =  4  result =  0.7161458333333333
#
# Pregnancies Glucose BloodPressure Insulin
# k =  7  n_splits =  5  result =  0.6862405568287923
#
# Pregnancies Glucose BloodPressure BMI
# k =  9  n_splits =  8  result =  0.6940104166666667
#
# Pregnancies Glucose BloodPressure DiabetesPedigreeFunction
# k =  8  n_splits =  9  result =  0.7082839337285302
#
# Pregnancies Glucose BloodPressure Age
# k =  9  n_splits =  3  result =  0.7057291666666666
#
# Pregnancies Glucose SkinThickness Insulin
# k =  8  n_splits =  9  result =  0.7044079647362821
#
# Pregnancies Glucose SkinThickness BMI
# k =  8  n_splits =  6  result =  0.6848958333333334
#
# Pregnancies Glucose SkinThickness DiabetesPedigreeFunction
# k =  9  n_splits =  3  result =  0.6822916666666666
#
# Pregnancies Glucose SkinThickness Age
# k =  9  n_splits =  5  result =  0.6939733469145234
#
# Pregnancies Glucose Insulin BMI
# k =  8  n_splits =  9  result =  0.6730810153518771
#
# Pregnancies Glucose Insulin DiabetesPedigreeFunction
# k =  4  n_splits =  9  result =  0.6599787201702385
#
# Pregnancies Glucose Insulin Age
# k =  9  n_splits =  8  result =  0.6653645833333333
#
# Pregnancies Glucose BMI DiabetesPedigreeFunction
# k =  7  n_splits =  3  result =  0.671875
#
# Pregnancies Glucose BMI Age
# k =  9  n_splits =  8  result =  0.68359375
#
# Pregnancies Glucose DiabetesPedigreeFunction Age
# k =  7  n_splits =  9  result =  0.6861225110199118
#
# Pregnancies BloodPressure SkinThickness Insulin
# k =  9  n_splits =  2  result =  0.7799479166666667
#
# Pregnancies BloodPressure SkinThickness BMI
# k =  9  n_splits =  4  result =  0.7565104166666666
#
# Pregnancies BloodPressure SkinThickness DiabetesPedigreeFunction
# k =  9  n_splits =  7  result =  0.7577147623019184
#
# Pregnancies BloodPressure SkinThickness Age
# k =  7  n_splits =  4  result =  0.7526041666666666
#
# Pregnancies BloodPressure Insulin BMI
# k =  8  n_splits =  4  result =  0.73828125
#
# Pregnancies BloodPressure Insulin DiabetesPedigreeFunction
# k =  8  n_splits =  9  result =  0.7578355373157014
#
# Pregnancies BloodPressure Insulin Age
# k =  9  n_splits =  4  result =  0.7304687500000001
#
# Pregnancies BloodPressure BMI DiabetesPedigreeFunction
# k =  9  n_splits =  4  result =  0.7473958333333333
#
# Pregnancies BloodPressure BMI Age
# k =  9  n_splits =  5  result =  0.7305152363975893
#
# Pregnancies BloodPressure DiabetesPedigreeFunction Age
# k =  7  n_splits =  4  result =  0.7513020833333334
#
# Pregnancies SkinThickness Insulin BMI
# k =  5  n_splits =  2  result =  0.7565104166666667
#
# Pregnancies SkinThickness Insulin DiabetesPedigreeFunction
# k =  9  n_splits =  3  result =  0.7630208333333334
#
# Pregnancies SkinThickness Insulin Age
# k =  9  n_splits =  2  result =  0.7447916666666667
#
# Pregnancies SkinThickness BMI DiabetesPedigreeFunction
# k =  7  n_splits =  3  result =  0.73828125
#
# Pregnancies SkinThickness BMI Age
# k =  9  n_splits =  2  result =  0.73046875
#
# Pregnancies SkinThickness DiabetesPedigreeFunction Age
# k =  8  n_splits =  3  result =  0.7565104166666666
#
# Pregnancies Insulin BMI DiabetesPedigreeFunction
# k =  9  n_splits =  6  result =  0.7395833333333334
#
# Pregnancies Insulin BMI Age
# k =  9  n_splits =  2  result =  0.71875
#
# Pregnancies Insulin DiabetesPedigreeFunction Age
# k =  9  n_splits =  3  result =  0.7552083333333334
#
# Pregnancies BMI DiabetesPedigreeFunction Age
# k =  9  n_splits =  6  result =  0.7604166666666666
#
# Glucose BloodPressure SkinThickness Insulin
# k =  9  n_splits =  4  result =  0.7109375
#
# Glucose BloodPressure SkinThickness BMI
# k =  8  n_splits =  4  result =  0.6940104166666667
#
# Glucose BloodPressure SkinThickness DiabetesPedigreeFunction
# k =  8  n_splits =  6  result =  0.7096354166666666
#
# Glucose BloodPressure SkinThickness Age
# k =  8  n_splits =  2  result =  0.7005208333333333
#
# Glucose BloodPressure Insulin BMI
# k =  5  n_splits =  4  result =  0.6640625
#
# Glucose BloodPressure Insulin DiabetesPedigreeFunction
# k =  4  n_splits =  7  result =  0.6704753961634695
#
# Glucose BloodPressure Insulin Age
# k =  8  n_splits =  8  result =  0.6627604166666667
#
# Glucose BloodPressure BMI DiabetesPedigreeFunction
# k =  9  n_splits =  4  result =  0.6888020833333333
#
# Glucose BloodPressure BMI Age
# k =  8  n_splits =  6  result =  0.67578125
#
# Glucose BloodPressure DiabetesPedigreeFunction Age
# k =  6  n_splits =  3  result =  0.6783854166666666
#
# Glucose SkinThickness Insulin BMI
# k =  8  n_splits =  9  result =  0.6680042559659524
#
# Glucose SkinThickness Insulin DiabetesPedigreeFunction
# k =  9  n_splits =  8  result =  0.6783854166666666
#
# Glucose SkinThickness Insulin Age
# k =  6  n_splits =  8  result =  0.6588541666666666
#
# Glucose SkinThickness BMI DiabetesPedigreeFunction
# k =  9  n_splits =  5  result =  0.6627875392581275
#
# Glucose SkinThickness BMI Age
# k =  6  n_splits =  6  result =  0.6640625
#
# Glucose SkinThickness DiabetesPedigreeFunction Age
# k =  8  n_splits =  3  result =  0.6705729166666666
#
# Glucose Insulin BMI DiabetesPedigreeFunction
# k =  8  n_splits =  3  result =  0.6536458333333334
#
# Glucose Insulin BMI Age
# k =  8  n_splits =  9  result =  0.6576227390180879
#
# Glucose Insulin DiabetesPedigreeFunction Age
# k =  7  n_splits =  5  result =  0.6588065529242
#
# Glucose BMI DiabetesPedigreeFunction Age
# k =  4  n_splits =  5  result =  0.6718529836176894
#
# BloodPressure SkinThickness Insulin BMI
# k =  5  n_splits =  8  result =  0.75390625
#
# BloodPressure SkinThickness Insulin DiabetesPedigreeFunction
# k =  7  n_splits =  7  result =  0.7565232932205409
#
# BloodPressure SkinThickness Insulin Age
# k =  6  n_splits =  9  result =  0.756482748138015
#
# BloodPressure SkinThickness BMI DiabetesPedigreeFunction
# k =  6  n_splits =  4  result =  0.734375
#
# BloodPressure SkinThickness BMI Age
# k =  9  n_splits =  4  result =  0.7356770833333334
#
# BloodPressure SkinThickness DiabetesPedigreeFunction Age
# k =  9  n_splits =  4  result =  0.7486979166666666
#
# BloodPressure Insulin BMI DiabetesPedigreeFunction
# k =  5  n_splits =  7  result =  0.7305969260097701
#
# BloodPressure Insulin BMI Age
# k =  9  n_splits =  4  result =  0.7291666666666666
#
# BloodPressure Insulin DiabetesPedigreeFunction Age
# k =  9  n_splits =  9  result =  0.7435020519835842
#
# BloodPressure BMI DiabetesPedigreeFunction Age
# k =  9  n_splits =  5  result =  0.7330956625074272
#
# SkinThickness Insulin BMI DiabetesPedigreeFunction
# k =  9  n_splits =  7  result =  0.7527225068509472
#
# SkinThickness Insulin BMI Age
# k =  7  n_splits =  2  result =  0.7395833333333334
#
# SkinThickness Insulin DiabetesPedigreeFunction Age
# k =  8  n_splits =  9  result =  0.7473628210974312
#
# SkinThickness BMI DiabetesPedigreeFunction Age
# k =  8  n_splits =  6  result =  0.7291666666666666
#
# Insulin BMI DiabetesPedigreeFunction Age
# k =  8  n_splits =  9  result =  0.7304909560723515

# %%
#RobustScaler
# Removal of 5 features
features = list(df1.columns)
features = [features[:-1]]

scaler = RobustScaler()
for feature in features:
    df1[feature] = scaler.fit_transform(df1[feature])

l = []
for i in range(0,8):
    for j in range(i+1,8):
        for k in range(j+1,8):
            for m in range(k+1,8):
                for o in range(m+1,8):
                    l.append([i,j,k,m,o])


                    
#Create X and y variable
for i in l: 
    print(features[0][i[0]],features[0][i[1]],features[0][i[2]],features[0][i[3]],features[0][i[4]])
    X = df1.drop(columns=['Outcome', features[0][i[0]],features[0][i[1]],features[0][i[2]],features[0][i[3]],features[0][i[4]]])
    y = df1['Outcome']
    func1()
# Out:
# Pregnancies Glucose BloodPressure SkinThickness Insulin
# k =  9  n_splits =  5  result =  0.712282488753077
#
# Pregnancies Glucose BloodPressure SkinThickness BMI
# k =  5  n_splits =  6  result =  0.6927083333333334
#
# Pregnancies Glucose BloodPressure SkinThickness DiabetesPedigreeFunction
# k =  8  n_splits =  7  result =  0.7042654593113309
#
# Pregnancies Glucose BloodPressure SkinThickness Age
# k =  8  n_splits =  2  result =  0.7109375
#
# Pregnancies Glucose BloodPressure Insulin BMI
# k =  6  n_splits =  2  result =  0.671875
#
# Pregnancies Glucose BloodPressure Insulin DiabetesPedigreeFunction
# k =  9  n_splits =  9  result =  0.6795561635506916
#
# Pregnancies Glucose BloodPressure Insulin Age
# k =  9  n_splits =  3  result =  0.671875
#
# Pregnancies Glucose BloodPressure BMI DiabetesPedigreeFunction
# k =  7  n_splits =  5  result =  0.68882098293863
#
# Pregnancies Glucose BloodPressure BMI Age
# k =  7  n_splits =  8  result =  0.69140625
#
# Pregnancies Glucose BloodPressure DiabetesPedigreeFunction Age
# k =  9  n_splits =  3  result =  0.6940104166666666
#
# Pregnancies Glucose SkinThickness Insulin BMI
# k =  9  n_splits =  2  result =  0.6640625
#
# Pregnancies Glucose SkinThickness Insulin DiabetesPedigreeFunction
# k =  3  n_splits =  3  result =  0.68359375
#
# Pregnancies Glucose SkinThickness Insulin Age
# k =  2  n_splits =  6  result =  0.66796875
#
# Pregnancies Glucose SkinThickness BMI DiabetesPedigreeFunction
# k =  5  n_splits =  9  result =  0.6745554035567716
#
# Pregnancies Glucose SkinThickness BMI Age
# k =  8  n_splits =  5  result =  0.6705882352941176
#
# Pregnancies Glucose SkinThickness DiabetesPedigreeFunction Age
# k =  5  n_splits =  9  result =  0.6704210366317069
#
# Pregnancies Glucose Insulin BMI DiabetesPedigreeFunction
# k =  8  n_splits =  2  result =  0.6471354166666667
#
# Pregnancies Glucose Insulin BMI Age
# k =  8  n_splits =  2  result =  0.6549479166666667
#
# Pregnancies Glucose Insulin DiabetesPedigreeFunction Age
# k =  2  n_splits =  9  result =  0.6690834473324213
#
# Pregnancies Glucose BMI DiabetesPedigreeFunction Age
# k =  9  n_splits =  6  result =  0.6666666666666666
#
# Pregnancies BloodPressure SkinThickness Insulin BMI
# k =  9  n_splits =  2  result =  0.7682291666666667
#
# Pregnancies BloodPressure SkinThickness Insulin DiabetesPedigreeFunction
# k =  9  n_splits =  3  result =  0.7604166666666666
#
# Pregnancies BloodPressure SkinThickness Insulin Age
# k =  9  n_splits =  2  result =  0.7473958333333333
#
# Pregnancies BloodPressure SkinThickness BMI DiabetesPedigreeFunction
# k =  8  n_splits =  4  result =  0.7486979166666666
#
# Pregnancies BloodPressure SkinThickness BMI Age
# k =  9  n_splits =  2  result =  0.7356770833333334
#
# Pregnancies BloodPressure SkinThickness DiabetesPedigreeFunction Age
# k =  9  n_splits =  2  result =  0.7552083333333334
#
# Pregnancies BloodPressure Insulin BMI DiabetesPedigreeFunction
# k =  9  n_splits =  8  result =  0.7395833333333334
#
# Pregnancies BloodPressure Insulin BMI Age
# k =  5  n_splits =  4  result =  0.7278645833333333
#
# Pregnancies BloodPressure Insulin DiabetesPedigreeFunction Age
# k =  8  n_splits =  4  result =  0.7434895833333333
#
# Pregnancies BloodPressure BMI DiabetesPedigreeFunction Age
# k =  9  n_splits =  5  result =  0.733163568457686
#
# Pregnancies SkinThickness Insulin BMI DiabetesPedigreeFunction
# k =  8  n_splits =  2  result =  0.7526041666666667
#
# Pregnancies SkinThickness Insulin BMI Age
# k =  6  n_splits =  3  result =  0.7447916666666666
#
# Pregnancies SkinThickness Insulin DiabetesPedigreeFunction Age
# k =  7  n_splits =  3  result =  0.7395833333333334
#
# Pregnancies SkinThickness BMI DiabetesPedigreeFunction Age
# k =  9  n_splits =  2  result =  0.7473958333333333
#
# Pregnancies Insulin BMI DiabetesPedigreeFunction Age
# k =  9  n_splits =  4  result =  0.7447916666666667
#
# Glucose BloodPressure SkinThickness Insulin BMI
# k =  9  n_splits =  2  result =  0.6822916666666666
#
# Glucose BloodPressure SkinThickness Insulin DiabetesPedigreeFunction
# k =  9  n_splits =  4  result =  0.7174479166666666
#
# Glucose BloodPressure SkinThickness Insulin Age
# k =  4  n_splits =  6  result =  0.69140625
#
# Glucose BloodPressure SkinThickness BMI DiabetesPedigreeFunction
# k =  7  n_splits =  4  result =  0.7109375000000001
#
# Glucose BloodPressure SkinThickness BMI Age
# k =  2  n_splits =  6  result =  0.6692708333333334
#
# Glucose BloodPressure SkinThickness DiabetesPedigreeFunction Age
# k =  8  n_splits =  3  result =  0.69140625
#
# Glucose BloodPressure Insulin BMI DiabetesPedigreeFunction
# k =  9  n_splits =  7  result =  0.665304420350292
#
# Glucose BloodPressure Insulin BMI Age
# k =  8  n_splits =  4  result =  0.6679687499999999
#
# Glucose BloodPressure Insulin DiabetesPedigreeFunction Age
# k =  8  n_splits =  3  result =  0.671875
#
# Glucose BloodPressure BMI DiabetesPedigreeFunction Age
# k =  9  n_splits =  4  result =  0.67578125
#
# Glucose SkinThickness Insulin BMI DiabetesPedigreeFunction
# k =  6  n_splits =  5  result =  0.6523809523809524
#
# Glucose SkinThickness Insulin BMI Age
# k =  4  n_splits =  3  result =  0.6640625
#
# Glucose SkinThickness Insulin DiabetesPedigreeFunction Age
# k =  9  n_splits =  6  result =  0.6614583333333334
#
# Glucose SkinThickness BMI DiabetesPedigreeFunction Age
# k =  3  n_splits =  9  result =  0.6629274965800274
#
# Glucose Insulin BMI DiabetesPedigreeFunction Age
# k =  9  n_splits =  5  result =  0.6497156438332908
#
# BloodPressure SkinThickness Insulin BMI DiabetesPedigreeFunction
# k =  3  n_splits =  4  result =  0.7643229166666666
#
# BloodPressure SkinThickness Insulin BMI Age
# k =  6  n_splits =  6  result =  0.7565104166666666
#
# BloodPressure SkinThickness Insulin DiabetesPedigreeFunction Age
# k =  9  n_splits =  3  result =  0.7604166666666666
#
# BloodPressure SkinThickness BMI DiabetesPedigreeFunction Age
# k =  3  n_splits =  2  result =  0.7252604166666667
#
# BloodPressure Insulin BMI DiabetesPedigreeFunction Age
# k =  5  n_splits =  7  result =  0.7188371261765756
#
# SkinThickness Insulin BMI DiabetesPedigreeFunction Age
# k =  9  n_splits =  7  result =  0.7344334564518051

# %%
#RobustScaler
# Removal of 6 features
features = list(df1.columns)
features = [features[:-1]]

scaler = RobustScaler()
for feature in features:
    df1[feature] = scaler.fit_transform(df1[feature])

l = []
for i in range(0,8):
    for j in range(i+1,8):
        for k in range(j+1,8):
            for m in range(k+1,8):
                for o in range(m+1,8):
                    for p in range(o+1,8):
                        l.append([i,j,k,m,o,p])


                    
#Create X and y variable
for i in l: 
    print(features[0][i[0]],features[0][i[1]],features[0][i[2]],features[0][i[3]],features[0][i[4]],features[0][i[5]])
    X = df1.drop(columns=['Outcome', features[0][i[0]],features[0][i[1]],features[0][i[2]],features[0][i[3]],features[0][i[4]],features[0][i[5]]])
    y = df1['Outcome']
    func1()
# Out:
# Pregnancies Glucose BloodPressure SkinThickness Insulin BMI
# k =  7  n_splits =  2  result =  0.6770833333333333
#
# Pregnancies Glucose BloodPressure SkinThickness Insulin DiabetesPedigreeFunction
# k =  9  n_splits =  3  result =  0.6888020833333334
#
# Pregnancies Glucose BloodPressure SkinThickness Insulin Age
# k =  8  n_splits =  9  result =  0.6938896488828089
#
# Pregnancies Glucose BloodPressure SkinThickness BMI DiabetesPedigreeFunction
# k =  9  n_splits =  4  result =  0.703125
#
# Pregnancies Glucose BloodPressure SkinThickness BMI Age
# k =  7  n_splits =  6  result =  0.66796875
#
# Pregnancies Glucose BloodPressure SkinThickness DiabetesPedigreeFunction Age
# k =  3  n_splits =  3  result =  0.6875
#
# Pregnancies Glucose BloodPressure Insulin BMI DiabetesPedigreeFunction
# k =  9  n_splits =  2  result =  0.65234375
#
# Pregnancies Glucose BloodPressure Insulin BMI Age
# k =  8  n_splits =  8  result =  0.6575520833333334
#
# Pregnancies Glucose BloodPressure Insulin DiabetesPedigreeFunction Age
# k =  2  n_splits =  6  result =  0.6731770833333334
#
# Pregnancies Glucose BloodPressure BMI DiabetesPedigreeFunction Age
# k =  7  n_splits =  2  result =  0.6744791666666667
#
# Pregnancies Glucose SkinThickness Insulin BMI DiabetesPedigreeFunction
# k =  4  n_splits =  9  result =  0.6510107919136647
#
# Pregnancies Glucose SkinThickness Insulin BMI Age
# k =  8  n_splits =  2  result =  0.6458333333333334
#
# Pregnancies Glucose SkinThickness Insulin DiabetesPedigreeFunction Age
# k =  2  n_splits =  5  result =  0.6562431033019268
#
# Pregnancies Glucose SkinThickness BMI DiabetesPedigreeFunction Age
# k =  8  n_splits =  3  result =  0.6575520833333334
#
# Pregnancies Glucose Insulin BMI DiabetesPedigreeFunction Age
# k =  2  n_splits =  4  result =  0.6315104166666667
#
# Pregnancies BloodPressure SkinThickness Insulin BMI DiabetesPedigreeFunction
# k =  6  n_splits =  3  result =  0.7513020833333334
#
# Pregnancies BloodPressure SkinThickness Insulin BMI Age
# k =  8  n_splits =  4  result =  0.7434895833333334
#
# Pregnancies BloodPressure SkinThickness Insulin DiabetesPedigreeFunction Age
# k =  9  n_splits =  3  result =  0.7578125
#
# Pregnancies BloodPressure SkinThickness BMI DiabetesPedigreeFunction Age
# k =  8  n_splits =  4  result =  0.7330729166666667
#
# Pregnancies BloodPressure Insulin BMI DiabetesPedigreeFunction Age
# k =  5  n_splits =  2  result =  0.7356770833333334
#
# Pregnancies SkinThickness Insulin BMI DiabetesPedigreeFunction Age
# k =  9  n_splits =  6  result =  0.7513020833333334
#
# Glucose BloodPressure SkinThickness Insulin BMI DiabetesPedigreeFunction
# k =  9  n_splits =  4  result =  0.68359375
#
# Glucose BloodPressure SkinThickness Insulin BMI Age
# k =  8  n_splits =  2  result =  0.6614583333333334
#
# Glucose BloodPressure SkinThickness Insulin DiabetesPedigreeFunction Age
# k =  8  n_splits =  4  result =  0.6848958333333333
#
# Glucose BloodPressure SkinThickness BMI DiabetesPedigreeFunction Age
# k =  2  n_splits =  5  result =  0.6861641626347509
#
# Glucose BloodPressure Insulin BMI DiabetesPedigreeFunction Age
# k =  7  n_splits =  8  result =  0.66015625
#
# Glucose SkinThickness Insulin BMI DiabetesPedigreeFunction Age
# k =  6  n_splits =  4  result =  0.6497395833333333
#
# BloodPressure SkinThickness Insulin BMI DiabetesPedigreeFunction Age
# k =  8  n_splits =  2  result =  0.7278645833333334

# %% [markdown]
# # Modeling with StandardScaler

# %%
#StandardScaler
# Removing 1 Feature and Selecting 7 other features
features = list(df1.columns)
features = [features[:-1]]

scaler = StandardScaler()
for feature in features:
    df1[feature] = scaler.fit_transform(df1[feature])


#Create X and y variable
for feature in features[0]: 
    print(feature)
    X = df1.drop(columns=['Outcome',feature])
    y = df1['Outcome']
    func1()
# Out:
# Pregnancies
# k =  9  n_splits =  3  result =  0.7760416666666666
#
# Glucose
# k =  9  n_splits =  3  result =  0.6927083333333334
#
# BloodPressure
# k =  7  n_splits =  3  result =  0.76171875
#
# SkinThickness
# k =  7  n_splits =  3  result =  0.7591145833333334
#
# Insulin
# k =  9  n_splits =  3  result =  0.7552083333333334
#
# BMI
# k =  5  n_splits =  7  result =  0.7370427737400214
#
# DiabetesPedigreeFunction
# k =  7  n_splits =  3  result =  0.7591145833333334
#
# Age
# k =  9  n_splits =  3  result =  0.7513020833333334

# %%
#StandardScaler
# Removal of 2 features selecting 6 other 
features = list(df1.columns)
features = [features[:-1]]

scaler = StandardScaler()
for feature in features:
    df1[feature] = scaler.fit_transform(df1[feature])

l = []
for i in range(0,8):
    for j in range(i+1,8):
        l.append([i,j])


#Create X and y variable
for i in l: 
    print(features[0][i[0]],features[0][i[1]])
    X = df1.drop(columns=['Outcome', features[0][i[0]],features[0][i[1]]])
    y = df1['Outcome']
    func1()
# Out:
# Pregnancies Glucose
# k =  9  n_splits =  9  result =  0.7044383644930841
#
# Pregnancies BloodPressure
# k =  9  n_splits =  4  result =  0.7786458333333333
#
# Pregnancies SkinThickness
# k =  9  n_splits =  3  result =  0.78125
#
# Pregnancies Insulin
# k =  9  n_splits =  3  result =  0.7669270833333334
#
# Pregnancies BMI
# k =  9  n_splits =  9  result =  0.7460860313117496
#
# Pregnancies DiabetesPedigreeFunction
# k =  9  n_splits =  9  result =  0.7643714850281198
#
# Pregnancies Age
# k =  9  n_splits =  5  result =  0.746150581444699
#
# Glucose BloodPressure
# k =  5  n_splits =  7  result =  0.7044560943643513
#
# Glucose SkinThickness
# k =  8  n_splits =  3  result =  0.6875
#
# Glucose Insulin
# k =  9  n_splits =  2  result =  0.6744791666666667
#
# Glucose BMI
# k =  9  n_splits =  3  result =  0.67578125
#
# Glucose DiabetesPedigreeFunction
# k =  9  n_splits =  2  result =  0.671875
#
# Glucose Age
# k =  9  n_splits =  9  result =  0.6707250341997263
#
# BloodPressure SkinThickness
# k =  9  n_splits =  4  result =  0.7630208333333333
#
# BloodPressure Insulin
# k =  9  n_splits =  4  result =  0.7486979166666666
#
# BloodPressure BMI
# k =  7  n_splits =  7  result =  0.7435124508519004
#
# BloodPressure DiabetesPedigreeFunction
# k =  9  n_splits =  3  result =  0.7578125
#
# BloodPressure Age
# k =  9  n_splits =  7  result =  0.7500417014178483
#
# SkinThickness Insulin
# k =  8  n_splits =  4  result =  0.7721354166666666
#
# SkinThickness BMI
# k =  9  n_splits =  7  result =  0.7552722506850947
#
# SkinThickness DiabetesPedigreeFunction
# k =  9  n_splits =  3  result =  0.7708333333333334
#
# SkinThickness Age
# k =  8  n_splits =  3  result =  0.7552083333333334
#
# Insulin BMI
# k =  8  n_splits =  3  result =  0.7291666666666666
#
# Insulin DiabetesPedigreeFunction
# k =  9  n_splits =  3  result =  0.75390625
#
# Insulin Age
# k =  8  n_splits =  3  result =  0.7395833333333334
#
# BMI DiabetesPedigreeFunction
# k =  9  n_splits =  2  result =  0.7317708333333333
#
# BMI Age
# k =  6  n_splits =  9  result =  0.7291685666514668
#
# DiabetesPedigreeFunction Age
# k =  8  n_splits =  7  result =  0.7526510187060645

# %%
#StandardScaler
# Removal of 3 features 
features = list(df1.columns)
features = [features[:-1]]

scaler = StandardScaler()
for feature in features:
    df1[feature] = scaler.fit_transform(df1[feature])

l = []
for i in range(0,8):
    for j in range(i+1,8):
        for k in range(j+1,8):
            l.append([i,j,k])


    
#Create X and y variable
for i in l: 
    print(features[0][i[0]],features[0][i[1]],features[0][i[2]])
    X = df1.drop(columns=['Outcome', features[0][i[0]],features[0][i[1]],features[0][i[2]]])
    y = df1['Outcome']
    func1()
# Out:
# Pregnancies Glucose BloodPressure
# k =  7  n_splits =  3  result =  0.7109375
#
# Pregnancies Glucose SkinThickness
# k =  4  n_splits =  9  result =  0.7070071439428485
#
# Pregnancies Glucose Insulin
# k =  7  n_splits =  5  result =  0.6823189882013413
#
# Pregnancies Glucose BMI
# k =  8  n_splits =  9  result =  0.6822617419060648
#
# Pregnancies Glucose DiabetesPedigreeFunction
# k =  6  n_splits =  9  result =  0.6639762881896945
#
# Pregnancies Glucose Age
# k =  9  n_splits =  9  result =  0.693859249126007
#
# Pregnancies BloodPressure SkinThickness
# k =  7  n_splits =  2  result =  0.77734375
#
# Pregnancies BloodPressure Insulin
# k =  9  n_splits =  2  result =  0.76171875
#
# Pregnancies BloodPressure BMI
# k =  9  n_splits =  2  result =  0.7447916666666667
#
# Pregnancies BloodPressure DiabetesPedigreeFunction
# k =  9  n_splits =  4  result =  0.7643229166666666
#
# Pregnancies BloodPressure Age
# k =  9  n_splits =  3  result =  0.7513020833333334
#
# Pregnancies SkinThickness Insulin
# k =  9  n_splits =  2  result =  0.76953125
#
# Pregnancies SkinThickness BMI
# k =  9  n_splits =  9  result =  0.7616963064295486
#
# Pregnancies SkinThickness DiabetesPedigreeFunction
# k =  9  n_splits =  5  result =  0.7643578643578642
#
# Pregnancies SkinThickness Age
# k =  9  n_splits =  2  result =  0.7526041666666666
#
# Pregnancies Insulin BMI
# k =  8  n_splits =  3  result =  0.7421875
#
# Pregnancies Insulin DiabetesPedigreeFunction
# k =  7  n_splits =  6  result =  0.7682291666666666
#
# Pregnancies Insulin Age
# k =  9  n_splits =  3  result =  0.7421875
#
# Pregnancies BMI DiabetesPedigreeFunction
# k =  9  n_splits =  9  result =  0.7382580939352485
#
# Pregnancies BMI Age
# k =  9  n_splits =  8  result =  0.7356770833333333
#
# Pregnancies DiabetesPedigreeFunction Age
# k =  9  n_splits =  7  result =  0.7578577385916836
#
# Glucose BloodPressure SkinThickness
# k =  8  n_splits =  7  result =  0.6991898010246633
#
# Glucose BloodPressure Insulin
# k =  8  n_splits =  4  result =  0.6861979166666666
#
# Glucose BloodPressure BMI
# k =  9  n_splits =  7  result =  0.6836411295126892
#
# Glucose BloodPressure DiabetesPedigreeFunction
# k =  9  n_splits =  7  result =  0.6965328249731918
#
# Glucose BloodPressure Age
# k =  9  n_splits =  6  result =  0.6861979166666666
#
# Glucose SkinThickness Insulin
# k =  5  n_splits =  2  result =  0.68359375
#
# Glucose SkinThickness BMI
# k =  9  n_splits =  7  result =  0.6875848921720482
#
# Glucose SkinThickness DiabetesPedigreeFunction
# k =  6  n_splits =  6  result =  0.68359375
#
# Glucose SkinThickness Age
# k =  8  n_splits =  3  result =  0.6744791666666666
#
# Glucose Insulin BMI
# k =  8  n_splits =  2  result =  0.6640625
#
# Glucose Insulin DiabetesPedigreeFunction
# k =  6  n_splits =  3  result =  0.6484375
#
# Glucose Insulin Age
# k =  8  n_splits =  3  result =  0.6614583333333334
#
# Glucose BMI DiabetesPedigreeFunction
# k =  7  n_splits =  3  result =  0.65625
#
# Glucose BMI Age
# k =  9  n_splits =  3  result =  0.6666666666666666
#
# Glucose DiabetesPedigreeFunction Age
# k =  6  n_splits =  6  result =  0.6588541666666666
#
# BloodPressure SkinThickness Insulin
# k =  9  n_splits =  4  result =  0.7643229166666667
#
# BloodPressure SkinThickness BMI
# k =  7  n_splits =  2  result =  0.7552083333333333
#
# BloodPressure SkinThickness DiabetesPedigreeFunction
# k =  9  n_splits =  9  result =  0.7616659066727466
#
# BloodPressure SkinThickness Age
# k =  9  n_splits =  3  result =  0.7565104166666666
#
# BloodPressure Insulin BMI
# k =  8  n_splits =  2  result =  0.7291666666666666
#
# BloodPressure Insulin DiabetesPedigreeFunction
# k =  9  n_splits =  2  result =  0.7526041666666667
#
# BloodPressure Insulin Age
# k =  7  n_splits =  9  result =  0.7434716522267821
#
# BloodPressure BMI DiabetesPedigreeFunction
# k =  8  n_splits =  8  result =  0.7330729166666667
#
# BloodPressure BMI Age
# k =  9  n_splits =  8  result =  0.7317708333333334
#
# BloodPressure DiabetesPedigreeFunction Age
# k =  9  n_splits =  3  result =  0.75390625
#
# SkinThickness Insulin BMI
# k =  9  n_splits =  3  result =  0.74609375
#
# SkinThickness Insulin DiabetesPedigreeFunction
# k =  9  n_splits =  2  result =  0.7630208333333333
#
# SkinThickness Insulin Age
# k =  9  n_splits =  2  result =  0.7473958333333333
#
# SkinThickness BMI DiabetesPedigreeFunction
# k =  8  n_splits =  3  result =  0.7513020833333334
#
# SkinThickness BMI Age
# k =  9  n_splits =  6  result =  0.7395833333333334
#
# SkinThickness DiabetesPedigreeFunction Age
# k =  9  n_splits =  9  result =  0.7539443684450524
#
# Insulin BMI DiabetesPedigreeFunction
# k =  7  n_splits =  6  result =  0.71875
#
# Insulin BMI Age
# k =  8  n_splits =  9  result =  0.7135582915336677
#
# Insulin DiabetesPedigreeFunction Age
# k =  9  n_splits =  3  result =  0.7565104166666666
#
# BMI DiabetesPedigreeFunction Age
# k =  6  n_splits =  8  result =  0.73046875

# %%
#StandardScaler
# Removal of 4 features
features = list(df1.columns)
features = [features[:-1]]

scaler = StandardScaler()
for feature in features:
    df1[feature] = scaler.fit_transform(df1[feature])

l = []
for i in range(0,8):
    for j in range(i+1,8):
        for k in range(j+1,8):
            for m in range(k+1,8):
                l.append([i,j,k,m])


    
#Create X and y variable
for i in l: 
    print(features[0][i[0]],features[0][i[1]],features[0][i[2]],features[0][i[3]])
    X = df1.drop(columns=['Outcome', features[0][i[0]],features[0][i[1]],features[0][i[2]],features[0][i[3]]])
    y = df1['Outcome']
    func1()
# Out:
# Pregnancies Glucose BloodPressure SkinThickness
# k =  8  n_splits =  3  result =  0.7174479166666666
#
# Pregnancies Glucose BloodPressure Insulin
# k =  9  n_splits =  2  result =  0.7018229166666667
#
# Pregnancies Glucose BloodPressure BMI
# k =  9  n_splits =  7  result =  0.6810437269152866
#
# Pregnancies Glucose BloodPressure DiabetesPedigreeFunction
# k =  9  n_splits =  9  result =  0.6978112175102598
#
# Pregnancies Glucose BloodPressure Age
# k =  9  n_splits =  2  result =  0.6953125
#
# Pregnancies Glucose SkinThickness Insulin
# k =  8  n_splits =  9  result =  0.7056999544003648
#
# Pregnancies Glucose SkinThickness BMI
# k =  8  n_splits =  3  result =  0.6966145833333334
#
# Pregnancies Glucose SkinThickness DiabetesPedigreeFunction
# k =  6  n_splits =  9  result =  0.6835385316917465
#
# Pregnancies Glucose SkinThickness Age
# k =  6  n_splits =  6  result =  0.6822916666666666
#
# Pregnancies Glucose Insulin BMI
# k =  8  n_splits =  9  result =  0.6665602675178599
#
# Pregnancies Glucose Insulin DiabetesPedigreeFunction
# k =  4  n_splits =  2  result =  0.6575520833333333
#
# Pregnancies Glucose Insulin Age
# k =  6  n_splits =  9  result =  0.6574707402340781
#
# Pregnancies Glucose BMI DiabetesPedigreeFunction
# k =  5  n_splits =  7  result =  0.6576313594662219
#
# Pregnancies Glucose BMI Age
# k =  8  n_splits =  7  result =  0.6627904205885856
#
# Pregnancies Glucose DiabetesPedigreeFunction Age
# k =  5  n_splits =  5  result =  0.665359477124183
#
# Pregnancies BloodPressure SkinThickness Insulin
# k =  9  n_splits =  2  result =  0.78125
#
# Pregnancies BloodPressure SkinThickness BMI
# k =  9  n_splits =  4  result =  0.76953125
#
# Pregnancies BloodPressure SkinThickness DiabetesPedigreeFunction
# k =  9  n_splits =  2  result =  0.7643229166666667
#
# Pregnancies BloodPressure SkinThickness Age
# k =  9  n_splits =  3  result =  0.7578125
#
# Pregnancies BloodPressure Insulin BMI
# k =  6  n_splits =  2  result =  0.7408854166666667
#
# Pregnancies BloodPressure Insulin DiabetesPedigreeFunction
# k =  9  n_splits =  3  result =  0.7747395833333334
#
# Pregnancies BloodPressure Insulin Age
# k =  9  n_splits =  5  result =  0.7434682964094729
#
# Pregnancies BloodPressure BMI DiabetesPedigreeFunction
# k =  9  n_splits =  4  result =  0.74609375
#
# Pregnancies BloodPressure BMI Age
# k =  9  n_splits =  5  result =  0.7344707580001698
#
# Pregnancies BloodPressure DiabetesPedigreeFunction Age
# k =  8  n_splits =  5  result =  0.7435362023597317
#
# Pregnancies SkinThickness Insulin BMI
# k =  5  n_splits =  2  result =  0.7473958333333334
#
# Pregnancies SkinThickness Insulin DiabetesPedigreeFunction
# k =  9  n_splits =  3  result =  0.765625
#
# Pregnancies SkinThickness Insulin Age
# k =  9  n_splits =  2  result =  0.7473958333333333
#
# Pregnancies SkinThickness BMI DiabetesPedigreeFunction
# k =  7  n_splits =  8  result =  0.7565104166666666
#
# Pregnancies SkinThickness BMI Age
# k =  7  n_splits =  2  result =  0.7434895833333334
#
# Pregnancies SkinThickness DiabetesPedigreeFunction Age
# k =  9  n_splits =  9  result =  0.7734154126766986
#
# Pregnancies Insulin BMI DiabetesPedigreeFunction
# k =  9  n_splits =  2  result =  0.7434895833333333
#
# Pregnancies Insulin BMI Age
# k =  6  n_splits =  2  result =  0.7330729166666667
#
# Pregnancies Insulin DiabetesPedigreeFunction Age
# k =  7  n_splits =  5  result =  0.7435107376283847
#
# Pregnancies BMI DiabetesPedigreeFunction Age
# k =  9  n_splits =  6  result =  0.75390625
#
# Glucose BloodPressure SkinThickness Insulin
# k =  9  n_splits =  4  result =  0.7174479166666666
#
# Glucose BloodPressure SkinThickness BMI
# k =  9  n_splits =  7  result =  0.6849040867389491
#
# Glucose BloodPressure SkinThickness DiabetesPedigreeFunction
# k =  9  n_splits =  5  result =  0.7187335540276717
#
# Glucose BloodPressure SkinThickness Age
# k =  6  n_splits =  2  result =  0.6940104166666666
#
# Glucose BloodPressure Insulin BMI
# k =  8  n_splits =  2  result =  0.6692708333333333
#
# Glucose BloodPressure Insulin DiabetesPedigreeFunction
# k =  3  n_splits =  4  result =  0.6666666666666666
#
# Glucose BloodPressure Insulin Age
# k =  8  n_splits =  8  result =  0.6848958333333333
#
# Glucose BloodPressure BMI DiabetesPedigreeFunction
# k =  9  n_splits =  7  result =  0.6861432145835815
#
# Glucose BloodPressure BMI Age
# k =  8  n_splits =  6  result =  0.6809895833333334
#
# Glucose BloodPressure DiabetesPedigreeFunction Age
# k =  4  n_splits =  3  result =  0.671875
#
# Glucose SkinThickness Insulin BMI
# k =  4  n_splits =  4  result =  0.6614583333333334
#
# Glucose SkinThickness Insulin DiabetesPedigreeFunction
# k =  9  n_splits =  8  result =  0.6822916666666667
#
# Glucose SkinThickness Insulin Age
# k =  8  n_splits =  3  result =  0.6588541666666666
#
# Glucose SkinThickness BMI DiabetesPedigreeFunction
# k =  7  n_splits =  7  result =  0.6732276897414512
#
# Glucose SkinThickness BMI Age
# k =  8  n_splits =  3  result =  0.6640625
#
# Glucose SkinThickness DiabetesPedigreeFunction Age
# k =  8  n_splits =  3  result =  0.6640625
#
# Glucose Insulin BMI DiabetesPedigreeFunction
# k =  2  n_splits =  6  result =  0.6536458333333334
#
# Glucose Insulin BMI Age
# k =  9  n_splits =  3  result =  0.6536458333333334
#
# Glucose Insulin DiabetesPedigreeFunction Age
# k =  9  n_splits =  9  result =  0.6484116127070982
#
# Glucose BMI DiabetesPedigreeFunction Age
# k =  5  n_splits =  7  result =  0.6628976528059097
#
# BloodPressure SkinThickness Insulin BMI
# k =  3  n_splits =  4  result =  0.7578125
#
# BloodPressure SkinThickness Insulin DiabetesPedigreeFunction
# k =  6  n_splits =  4  result =  0.7578125
#
# BloodPressure SkinThickness Insulin Age
# k =  8  n_splits =  7  result =  0.7448349815322292
#
# BloodPressure SkinThickness BMI DiabetesPedigreeFunction
# k =  5  n_splits =  7  result =  0.7539616346955796
#
# BloodPressure SkinThickness BMI Age
# k =  6  n_splits =  4  result =  0.7421875
#
# BloodPressure SkinThickness DiabetesPedigreeFunction Age
# k =  9  n_splits =  9  result =  0.7513299893600851
#
# BloodPressure Insulin BMI DiabetesPedigreeFunction
# k =  4  n_splits =  4  result =  0.7265625
#
# BloodPressure Insulin BMI Age
# k =  9  n_splits =  8  result =  0.734375
#
# BloodPressure Insulin DiabetesPedigreeFunction Age
# k =  8  n_splits =  9  result =  0.7447940416476668
#
# BloodPressure BMI DiabetesPedigreeFunction Age
# k =  8  n_splits =  6  result =  0.7161458333333334
#
# SkinThickness Insulin BMI DiabetesPedigreeFunction
# k =  9  n_splits =  7  result =  0.7553199094483498
#
# SkinThickness Insulin BMI Age
# k =  7  n_splits =  8  result =  0.7408854166666667
#
# SkinThickness Insulin DiabetesPedigreeFunction Age
# k =  8  n_splits =  3  result =  0.7421875
#
# SkinThickness BMI DiabetesPedigreeFunction Age
# k =  8  n_splits =  3  result =  0.7421875
#
# Insulin BMI DiabetesPedigreeFunction Age
# k =  8  n_splits =  9  result =  0.7382276941784466

# %%
#StandardScaler
# Removal of 5 features
features = list(df1.columns)
features = [features[:-1]]

scaler = RobustScaler()
for feature in features:
    df1[feature] = scaler.fit_transform(df1[feature])

l = []
for i in range(0,8):
    for j in range(i+1,8):
        for k in range(j+1,8):
            for m in range(k+1,8):
                for o in range(m+1,8):
                    l.append([i,j,k,m,o])


                    
#Create X and y variable
for i in l: 
    print(features[0][i[0]],features[0][i[1]],features[0][i[2]],features[0][i[3]],features[0][i[4]])
    X = df1.drop(columns=['Outcome', features[0][i[0]],features[0][i[1]],features[0][i[2]],features[0][i[3]],features[0][i[4]]])
    y = df1['Outcome']
    func1()
# Out:
# Pregnancies Glucose BloodPressure SkinThickness Insulin
# k =  9  n_splits =  5  result =  0.712282488753077
#
# Pregnancies Glucose BloodPressure SkinThickness BMI
# k =  5  n_splits =  6  result =  0.6927083333333334
#
# Pregnancies Glucose BloodPressure SkinThickness DiabetesPedigreeFunction
# k =  8  n_splits =  7  result =  0.7055641606100321
#
# Pregnancies Glucose BloodPressure SkinThickness Age
# k =  8  n_splits =  2  result =  0.7109375
#
# Pregnancies Glucose BloodPressure Insulin BMI
# k =  6  n_splits =  2  result =  0.671875
#
# Pregnancies Glucose BloodPressure Insulin DiabetesPedigreeFunction
# k =  9  n_splits =  9  result =  0.6795561635506916
#
# Pregnancies Glucose BloodPressure Insulin Age
# k =  9  n_splits =  3  result =  0.671875
#
# Pregnancies Glucose BloodPressure BMI DiabetesPedigreeFunction
# k =  7  n_splits =  5  result =  0.6927085985909516
#
# Pregnancies Glucose BloodPressure BMI Age
# k =  7  n_splits =  8  result =  0.6927083333333334
#
# Pregnancies Glucose BloodPressure DiabetesPedigreeFunction Age
# k =  9  n_splits =  3  result =  0.6953125
#
# Pregnancies Glucose SkinThickness Insulin BMI
# k =  9  n_splits =  2  result =  0.6640625
#
# Pregnancies Glucose SkinThickness Insulin DiabetesPedigreeFunction
# k =  3  n_splits =  3  result =  0.6822916666666666
#
# Pregnancies Glucose SkinThickness Insulin Age
# k =  2  n_splits =  6  result =  0.66796875
#
# Pregnancies Glucose SkinThickness BMI DiabetesPedigreeFunction
# k =  9  n_splits =  6  result =  0.67578125
#
# Pregnancies Glucose SkinThickness BMI Age
# k =  8  n_splits =  5  result =  0.6705882352941176
#
# Pregnancies Glucose SkinThickness DiabetesPedigreeFunction Age
# k =  5  n_splits =  9  result =  0.6704210366317069
#
# Pregnancies Glucose Insulin BMI DiabetesPedigreeFunction
# k =  8  n_splits =  2  result =  0.6484375
#
# Pregnancies Glucose Insulin BMI Age
# k =  8  n_splits =  2  result =  0.6536458333333334
#
# Pregnancies Glucose Insulin DiabetesPedigreeFunction Age
# k =  2  n_splits =  9  result =  0.6703754369965039
#
# Pregnancies Glucose BMI DiabetesPedigreeFunction Age
# k =  9  n_splits =  6  result =  0.6653645833333334
#
# Pregnancies BloodPressure SkinThickness Insulin BMI
# k =  9  n_splits =  2  result =  0.7682291666666667
#
# Pregnancies BloodPressure SkinThickness Insulin DiabetesPedigreeFunction
# k =  9  n_splits =  3  result =  0.7604166666666666
#
# Pregnancies BloodPressure SkinThickness Insulin Age
# k =  9  n_splits =  2  result =  0.7473958333333333
#
# Pregnancies BloodPressure SkinThickness BMI DiabetesPedigreeFunction
# k =  8  n_splits =  4  result =  0.74609375
#
# Pregnancies BloodPressure SkinThickness BMI Age
# k =  9  n_splits =  2  result =  0.7356770833333334
#
# Pregnancies BloodPressure SkinThickness DiabetesPedigreeFunction Age
# k =  9  n_splits =  2  result =  0.7552083333333334
#
# Pregnancies BloodPressure Insulin BMI DiabetesPedigreeFunction
# k =  9  n_splits =  8  result =  0.7408854166666667
#
# Pregnancies BloodPressure Insulin BMI Age
# k =  5  n_splits =  4  result =  0.7278645833333333
#
# Pregnancies BloodPressure Insulin DiabetesPedigreeFunction Age
# k =  8  n_splits =  4  result =  0.7434895833333333
#
# Pregnancies BloodPressure BMI DiabetesPedigreeFunction Age
# k =  9  n_splits =  5  result =  0.7331465919701214
#
# Pregnancies SkinThickness Insulin BMI DiabetesPedigreeFunction
# k =  8  n_splits =  2  result =  0.7526041666666667
#
# Pregnancies SkinThickness Insulin BMI Age
# k =  6  n_splits =  3  result =  0.7447916666666666
#
# Pregnancies SkinThickness Insulin DiabetesPedigreeFunction Age
# k =  7  n_splits =  3  result =  0.7395833333333334
#
# Pregnancies SkinThickness BMI DiabetesPedigreeFunction Age
# k =  9  n_splits =  2  result =  0.7473958333333333
#
# Pregnancies Insulin BMI DiabetesPedigreeFunction Age
# k =  9  n_splits =  4  result =  0.7447916666666667
#
# Glucose BloodPressure SkinThickness Insulin BMI
# k =  9  n_splits =  2  result =  0.6822916666666666
#
# Glucose BloodPressure SkinThickness Insulin DiabetesPedigreeFunction
# k =  9  n_splits =  4  result =  0.7174479166666666
#
# Glucose BloodPressure SkinThickness Insulin Age
# k =  4  n_splits =  6  result =  0.69140625
#
# Glucose BloodPressure SkinThickness BMI DiabetesPedigreeFunction
# k =  7  n_splits =  4  result =  0.7083333333333334
#
# Glucose BloodPressure SkinThickness BMI Age
# k =  2  n_splits =  6  result =  0.6692708333333334
#
# Glucose BloodPressure SkinThickness DiabetesPedigreeFunction Age
# k =  8  n_splits =  3  result =  0.69140625
#
# Glucose BloodPressure Insulin BMI DiabetesPedigreeFunction
# k =  9  n_splits =  8  result =  0.66796875
#
# Glucose BloodPressure Insulin BMI Age
# k =  8  n_splits =  4  result =  0.6679687499999999
#
# Glucose BloodPressure Insulin DiabetesPedigreeFunction Age
# k =  8  n_splits =  3  result =  0.671875
#
# Glucose BloodPressure BMI DiabetesPedigreeFunction Age
# k =  9  n_splits =  4  result =  0.6770833333333333
#
# Glucose SkinThickness Insulin BMI DiabetesPedigreeFunction
# k =  6  n_splits =  5  result =  0.6562855445208385
#
# Glucose SkinThickness Insulin BMI Age
# k =  4  n_splits =  3  result =  0.6640625
#
# Glucose SkinThickness Insulin DiabetesPedigreeFunction Age
# k =  9  n_splits =  6  result =  0.6614583333333334
#
# Glucose SkinThickness BMI DiabetesPedigreeFunction Age
# k =  3  n_splits =  9  result =  0.6655418756649947
#
# Glucose Insulin BMI DiabetesPedigreeFunction Age
# k =  8  n_splits =  9  result =  0.6511627906976744
#
# BloodPressure SkinThickness Insulin BMI DiabetesPedigreeFunction
# k =  3  n_splits =  4  result =  0.7630208333333333
#
# BloodPressure SkinThickness Insulin BMI Age
# k =  6  n_splits =  6  result =  0.7565104166666666
#
# BloodPressure SkinThickness Insulin DiabetesPedigreeFunction Age
# k =  9  n_splits =  3  result =  0.7604166666666666
#
# BloodPressure SkinThickness BMI DiabetesPedigreeFunction Age
# k =  3  n_splits =  2  result =  0.72265625
#
# BloodPressure Insulin BMI DiabetesPedigreeFunction Age
# k =  5  n_splits =  7  result =  0.7175384248778744
#
# SkinThickness Insulin BMI DiabetesPedigreeFunction Age
# k =  9  n_splits =  7  result =  0.7344334564518051

# %%
#StandardScaler
# Removal of 6 features
features = list(df1.columns)
features = [features[:-1]]

scaler = StandardScaler()
for feature in features:
    df1[feature] = scaler.fit_transform(df1[feature])

l = []
for i in range(0,8):
    for j in range(i+1,8):
        for k in range(j+1,8):
            for m in range(k+1,8):
                for o in range(m+1,8):
                    for p in range(o+1,8):
                        l.append([i,j,k,m,o,p])


                    
#Create X and y variable
for i in l: 
    print(features[0][i[0]],features[0][i[1]],features[0][i[2]],features[0][i[3]],features[0][i[4]],features[0][i[5]])
    X = df1.drop(columns=['Outcome', features[0][i[0]],features[0][i[1]],features[0][i[2]],features[0][i[3]],features[0][i[4]],features[0][i[5]]])
    y = df1['Outcome']
    func1()
# Out:
# Pregnancies Glucose BloodPressure SkinThickness Insulin BMI
# k =  9  n_splits =  3  result =  0.6809895833333334
#
# Pregnancies Glucose BloodPressure SkinThickness Insulin DiabetesPedigreeFunction
# k =  9  n_splits =  3  result =  0.69921875
#
# Pregnancies Glucose BloodPressure SkinThickness Insulin Age
# k =  8  n_splits =  9  result =  0.6965192278461774
#
# Pregnancies Glucose BloodPressure SkinThickness BMI DiabetesPedigreeFunction
# k =  9  n_splits =  2  result =  0.69140625
#
# Pregnancies Glucose BloodPressure SkinThickness BMI Age
# k =  9  n_splits =  4  result =  0.6653645833333333
#
# Pregnancies Glucose BloodPressure SkinThickness DiabetesPedigreeFunction Age
# k =  4  n_splits =  9  result =  0.709515123879009
#
# Pregnancies Glucose BloodPressure Insulin BMI DiabetesPedigreeFunction
# k =  6  n_splits =  3  result =  0.6432291666666666
#
# Pregnancies Glucose BloodPressure Insulin BMI Age
# k =  2  n_splits =  5  result =  0.6562431033019268
#
# Pregnancies Glucose BloodPressure Insulin DiabetesPedigreeFunction Age
# k =  4  n_splits =  9  result =  0.6731114151086791
#
# Pregnancies Glucose BloodPressure BMI DiabetesPedigreeFunction Age
# k =  8  n_splits =  2  result =  0.6653645833333334
#
# Pregnancies Glucose SkinThickness Insulin BMI DiabetesPedigreeFunction
# k =  4  n_splits =  5  result =  0.6549528902470079
#
# Pregnancies Glucose SkinThickness Insulin BMI Age
# k =  8  n_splits =  2  result =  0.6458333333333333
#
# Pregnancies Glucose SkinThickness Insulin DiabetesPedigreeFunction Age
# k =  2  n_splits =  5  result =  0.6601561836855955
#
# Pregnancies Glucose SkinThickness BMI DiabetesPedigreeFunction Age
# k =  6  n_splits =  2  result =  0.65625
#
# Pregnancies Glucose Insulin BMI DiabetesPedigreeFunction Age
# k =  2  n_splits =  9  result =  0.6378172974616203
#
# Pregnancies BloodPressure SkinThickness Insulin BMI DiabetesPedigreeFunction
# k =  6  n_splits =  3  result =  0.75390625
#
# Pregnancies BloodPressure SkinThickness Insulin BMI Age
# k =  9  n_splits =  5  result =  0.743519225872167
#
# Pregnancies BloodPressure SkinThickness Insulin DiabetesPedigreeFunction Age
# k =  9  n_splits =  3  result =  0.7578125
#
# Pregnancies BloodPressure SkinThickness BMI DiabetesPedigreeFunction Age
# k =  8  n_splits =  7  result =  0.7226974860002383
#
# Pregnancies BloodPressure Insulin BMI DiabetesPedigreeFunction Age
# k =  9  n_splits =  2  result =  0.7369791666666666
#
# Pregnancies SkinThickness Insulin BMI DiabetesPedigreeFunction Age
# k =  9  n_splits =  6  result =  0.7526041666666666
#
# Glucose BloodPressure SkinThickness Insulin BMI DiabetesPedigreeFunction
# k =  9  n_splits =  4  result =  0.68359375
#
# Glucose BloodPressure SkinThickness Insulin BMI Age
# k =  8  n_splits =  6  result =  0.6588541666666666
#
# Glucose BloodPressure SkinThickness Insulin DiabetesPedigreeFunction Age
# k =  8  n_splits =  7  result =  0.6861193852019539
#
# Glucose BloodPressure SkinThickness BMI DiabetesPedigreeFunction Age
# k =  2  n_splits =  7  result =  0.6887287024901704
#
# Glucose BloodPressure Insulin BMI DiabetesPedigreeFunction Age
# k =  7  n_splits =  9  result =  0.6601459188326495
#
# Glucose SkinThickness Insulin BMI DiabetesPedigreeFunction Age
# k =  6  n_splits =  7  result =  0.6432384129631836
#
# BloodPressure SkinThickness Insulin BMI DiabetesPedigreeFunction Age
# k =  7  n_splits =  7  result =  0.7266293339687836

# %% [markdown]
# # Modeling with MinMaxScaler

# %%
# MinMaxScaler
# Removing 1 Feature and Selecting 7 other features
features = list(df1.columns)
features = [features[:-1]]

scaler = MinMaxScaler()
for feature in features:
    df1[feature] = scaler.fit_transform(df1[feature])


#Create X and y variable
for feature in features[0]: 
    print(feature)
    X = df1.drop(columns=['Outcome',feature])
    y = df1['Outcome']
    func1()
# Out:
# Pregnancies
# k =  7  n_splits =  3  result =  0.7747395833333334
#
# Glucose
# k =  7  n_splits =  2  result =  0.6848958333333334
#
# BloodPressure
# k =  4  n_splits =  4  result =  0.7591145833333334
#
# SkinThickness
# k =  6  n_splits =  3  result =  0.7591145833333334
#
# Insulin
# k =  5  n_splits =  2  result =  0.7604166666666666
#
# BMI
# k =  5  n_splits =  6  result =  0.73828125
#
# DiabetesPedigreeFunction
# k =  9  n_splits =  3  result =  0.7565104166666666
#
# Age
# k =  8  n_splits =  5  result =  0.7383498854087089

# %%
# MinMaxScaler
# Removal of 2 features selecting 6 other 
features = list(df1.columns)
features = [features[:-1]]

scaler = MinMaxScaler()
for feature in features:
    df1[feature] = scaler.fit_transform(df1[feature])

l = []
for i in range(0,8):
    for j in range(i+1,8):
        l.append([i,j])


#Create X and y variable
for i in l: 
    print(features[0][i[0]],features[0][i[1]])
    X = df1.drop(columns=['Outcome', features[0][i[0]],features[0][i[1]]])
    y = df1['Outcome']
    func1()
# Out:
# Pregnancies Glucose
# k =  3  n_splits =  3  result =  0.7005208333333334
#
# Pregnancies BloodPressure
# k =  9  n_splits =  3  result =  0.7864583333333334
#
# Pregnancies SkinThickness
# k =  9  n_splits =  3  result =  0.7903645833333334
#
# Pregnancies Insulin
# k =  5  n_splits =  3  result =  0.7643229166666666
#
# Pregnancies BMI
# k =  9  n_splits =  8  result =  0.7578125
#
# Pregnancies DiabetesPedigreeFunction
# k =  9  n_splits =  3  result =  0.7721354166666666
#
# Pregnancies Age
# k =  9  n_splits =  3  result =  0.7604166666666666
#
# Glucose BloodPressure
# k =  7  n_splits =  4  result =  0.6953125000000001
#
# Glucose SkinThickness
# k =  9  n_splits =  9  result =  0.6862897096823226
#
# Glucose Insulin
# k =  7  n_splits =  9  result =  0.6718346253229974
#
# Glucose BMI
# k =  9  n_splits =  3  result =  0.6848958333333334
#
# Glucose DiabetesPedigreeFunction
# k =  9  n_splits =  6  result =  0.6770833333333334
#
# Glucose Age
# k =  8  n_splits =  2  result =  0.6627604166666667
#
# BloodPressure SkinThickness
# k =  9  n_splits =  4  result =  0.7643229166666666
#
# BloodPressure Insulin
# k =  9  n_splits =  2  result =  0.7552083333333333
#
# BloodPressure BMI
# k =  9  n_splits =  2  result =  0.7486979166666667
#
# BloodPressure DiabetesPedigreeFunction
# k =  9  n_splits =  3  result =  0.7604166666666666
#
# BloodPressure Age
# k =  8  n_splits =  3  result =  0.7447916666666666
#
# SkinThickness Insulin
# k =  9  n_splits =  4  result =  0.76171875
#
# SkinThickness BMI
# k =  9  n_splits =  6  result =  0.7578125
#
# SkinThickness DiabetesPedigreeFunction
# k =  7  n_splits =  3  result =  0.76171875
#
# SkinThickness Age
# k =  6  n_splits =  9  result =  0.7461164310685515
#
# Insulin BMI
# k =  9  n_splits =  2  result =  0.7421875
#
# Insulin DiabetesPedigreeFunction
# k =  7  n_splits =  3  result =  0.7513020833333334
#
# Insulin Age
# k =  8  n_splits =  6  result =  0.7356770833333334
#
# BMI DiabetesPedigreeFunction
# k =  7  n_splits =  3  result =  0.734375
#
# BMI Age
# k =  5  n_splits =  7  result =  0.7123317049922555
#
# DiabetesPedigreeFunction Age
# k =  6  n_splits =  3  result =  0.7408854166666666

# %%
# MinMaxScaler
# Removal of 3 features 
features = list(df1.columns)
features = [features[:-1]]

scaler = MinMaxScaler()
for feature in features:
    df1[feature] = scaler.fit_transform(df1[feature])

l = []
for i in range(0,8):
    for j in range(i+1,8):
        for k in range(j+1,8):
            l.append([i,j,k])


    
#Create X and y variable
for i in l: 
    print(features[0][i[0]],features[0][i[1]],features[0][i[2]])
    X = df1.drop(columns=['Outcome', features[0][i[0]],features[0][i[1]],features[0][i[2]]])
    y = df1['Outcome']
    func1()
# Out:
# Pregnancies Glucose BloodPressure
# k =  6  n_splits =  3  result =  0.7096354166666666
#
# Pregnancies Glucose SkinThickness
# k =  6  n_splits =  9  result =  0.7070375436996504
#
# Pregnancies Glucose Insulin
# k =  8  n_splits =  2  result =  0.6901041666666667
#
# Pregnancies Glucose BMI
# k =  9  n_splits =  3  result =  0.6927083333333334
#
# Pregnancies Glucose DiabetesPedigreeFunction
# k =  9  n_splits =  3  result =  0.6875
#
# Pregnancies Glucose Age
# k =  8  n_splits =  9  result =  0.6822161422708618
#
# Pregnancies BloodPressure SkinThickness
# k =  6  n_splits =  2  result =  0.7916666666666667
#
# Pregnancies BloodPressure Insulin
# k =  9  n_splits =  2  result =  0.7734375
#
# Pregnancies BloodPressure BMI
# k =  5  n_splits =  2  result =  0.7604166666666666
#
# Pregnancies BloodPressure DiabetesPedigreeFunction
# k =  9  n_splits =  7  result =  0.7734540688669129
#
# Pregnancies BloodPressure Age
# k =  7  n_splits =  3  result =  0.7526041666666666
#
# Pregnancies SkinThickness Insulin
# k =  9  n_splits =  4  result =  0.7721354166666666
#
# Pregnancies SkinThickness BMI
# k =  7  n_splits =  3  result =  0.76953125
#
# Pregnancies SkinThickness DiabetesPedigreeFunction
# k =  8  n_splits =  3  result =  0.7721354166666666
#
# Pregnancies SkinThickness Age
# k =  9  n_splits =  3  result =  0.7604166666666666
#
# Pregnancies Insulin BMI
# k =  9  n_splits =  4  result =  0.74609375
#
# Pregnancies Insulin DiabetesPedigreeFunction
# k =  9  n_splits =  3  result =  0.7682291666666666
#
# Pregnancies Insulin Age
# k =  9  n_splits =  2  result =  0.7447916666666666
#
# Pregnancies BMI DiabetesPedigreeFunction
# k =  6  n_splits =  4  result =  0.74609375
#
# Pregnancies BMI Age
# k =  8  n_splits =  4  result =  0.7395833333333334
#
# Pregnancies DiabetesPedigreeFunction Age
# k =  5  n_splits =  5  result =  0.7513114336643748
#
# Glucose BloodPressure SkinThickness
# k =  9  n_splits =  4  result =  0.6979166666666666
#
# Glucose BloodPressure Insulin
# k =  6  n_splits =  4  result =  0.69140625
#
# Glucose BloodPressure BMI
# k =  6  n_splits =  3  result =  0.6770833333333334
#
# Glucose BloodPressure DiabetesPedigreeFunction
# k =  8  n_splits =  4  result =  0.6888020833333334
#
# Glucose BloodPressure Age
# k =  6  n_splits =  6  result =  0.6822916666666666
#
# Glucose SkinThickness Insulin
# k =  6  n_splits =  4  result =  0.6875
#
# Glucose SkinThickness BMI
# k =  9  n_splits =  7  result =  0.6731919456690099
#
# Glucose SkinThickness DiabetesPedigreeFunction
# k =  7  n_splits =  6  result =  0.6901041666666666
#
# Glucose SkinThickness Age
# k =  8  n_splits =  2  result =  0.6744791666666666
#
# Glucose Insulin BMI
# k =  7  n_splits =  2  result =  0.6692708333333333
#
# Glucose Insulin DiabetesPedigreeFunction
# k =  9  n_splits =  3  result =  0.6666666666666666
#
# Glucose Insulin Age
# k =  8  n_splits =  2  result =  0.65625
#
# Glucose BMI DiabetesPedigreeFunction
# k =  9  n_splits =  7  result =  0.6561777671869414
#
# Glucose BMI Age
# k =  6  n_splits =  3  result =  0.6588541666666666
#
# Glucose DiabetesPedigreeFunction Age
# k =  8  n_splits =  3  result =  0.6549479166666666
#
# BloodPressure SkinThickness Insulin
# k =  5  n_splits =  4  result =  0.7539062500000001
#
# BloodPressure SkinThickness BMI
# k =  3  n_splits =  4  result =  0.7486979166666667
#
# BloodPressure SkinThickness DiabetesPedigreeFunction
# k =  9  n_splits =  4  result =  0.7643229166666666
#
# BloodPressure SkinThickness Age
# k =  9  n_splits =  7  result =  0.7487549148099605
#
# BloodPressure Insulin BMI
# k =  8  n_splits =  2  result =  0.74609375
#
# BloodPressure Insulin DiabetesPedigreeFunction
# k =  7  n_splits =  4  result =  0.765625
#
# BloodPressure Insulin Age
# k =  9  n_splits =  3  result =  0.7447916666666666
#
# BloodPressure BMI DiabetesPedigreeFunction
# k =  9  n_splits =  4  result =  0.7447916666666666
#
# BloodPressure BMI Age
# k =  8  n_splits =  4  result =  0.7395833333333334
#
# BloodPressure DiabetesPedigreeFunction Age
# k =  8  n_splits =  9  result =  0.739641282869737
#
# SkinThickness Insulin BMI
# k =  5  n_splits =  3  result =  0.7513020833333334
#
# SkinThickness Insulin DiabetesPedigreeFunction
# k =  7  n_splits =  7  result =  0.7591921839628262
#
# SkinThickness Insulin Age
# k =  9  n_splits =  3  result =  0.7447916666666666
#
# SkinThickness BMI DiabetesPedigreeFunction
# k =  8  n_splits =  7  result =  0.744799237459788
#
# SkinThickness BMI Age
# k =  9  n_splits =  5  result =  0.746243952126305
#
# SkinThickness DiabetesPedigreeFunction Age
# k =  8  n_splits =  7  result =  0.7526391040152508
#
# Insulin BMI DiabetesPedigreeFunction
# k =  9  n_splits =  6  result =  0.7434895833333334
#
# Insulin BMI Age
# k =  9  n_splits =  7  result =  0.7188132967949482
#
# Insulin DiabetesPedigreeFunction Age
# k =  8  n_splits =  3  result =  0.75
#
# BMI DiabetesPedigreeFunction Age
# k =  4  n_splits =  3  result =  0.7278645833333334

# %%
# MinMaxScaler
# Removal of 4 features
features = list(df1.columns)
features = [features[:-1]]

scaler = MinMaxScaler()
for feature in features:
    df1[feature] = scaler.fit_transform(df1[feature])

l = []
for i in range(0,8):
    for j in range(i+1,8):
        for k in range(j+1,8):
            for m in range(k+1,8):
                l.append([i,j,k,m])


    
#Create X and y variable
for i in l: 
    print(features[0][i[0]],features[0][i[1]],features[0][i[2]],features[0][i[3]])
    X = df1.drop(columns=['Outcome', features[0][i[0]],features[0][i[1]],features[0][i[2]],features[0][i[3]]])
    y = df1['Outcome']
    func1()
# Out:
# Pregnancies Glucose BloodPressure SkinThickness
# k =  8  n_splits =  3  result =  0.72265625
#
# Pregnancies Glucose BloodPressure Insulin
# k =  8  n_splits =  2  result =  0.7096354166666666
#
# Pregnancies Glucose BloodPressure BMI
# k =  9  n_splits =  3  result =  0.6861979166666666
#
# Pregnancies Glucose BloodPressure DiabetesPedigreeFunction
# k =  9  n_splits =  7  result =  0.7029667580126296
#
# Pregnancies Glucose BloodPressure Age
# k =  7  n_splits =  2  result =  0.7044270833333334
#
# Pregnancies Glucose SkinThickness Insulin
# k =  7  n_splits =  4  result =  0.7031250000000001
#
# Pregnancies Glucose SkinThickness BMI
# k =  8  n_splits =  3  result =  0.6901041666666666
#
# Pregnancies Glucose SkinThickness DiabetesPedigreeFunction
# k =  7  n_splits =  9  result =  0.6913208694330445
#
# Pregnancies Glucose SkinThickness Age
# k =  9  n_splits =  5  result =  0.6822510822510822
#
# Pregnancies Glucose Insulin BMI
# k =  8  n_splits =  9  result =  0.6730658154734762
#
# Pregnancies Glucose Insulin DiabetesPedigreeFunction
# k =  9  n_splits =  2  result =  0.6744791666666667
#
# Pregnancies Glucose Insulin Age
# k =  6  n_splits =  8  result =  0.66015625
#
# Pregnancies Glucose BMI DiabetesPedigreeFunction
# k =  9  n_splits =  7  result =  0.6640533778148457
#
# Pregnancies Glucose BMI Age
# k =  8  n_splits =  2  result =  0.6666666666666667
#
# Pregnancies Glucose DiabetesPedigreeFunction Age
# k =  4  n_splits =  6  result =  0.6653645833333334
#
# Pregnancies BloodPressure SkinThickness Insulin
# k =  5  n_splits =  2  result =  0.7864583333333333
#
# Pregnancies BloodPressure SkinThickness BMI
# k =  7  n_splits =  2  result =  0.7760416666666667
#
# Pregnancies BloodPressure SkinThickness DiabetesPedigreeFunction
# k =  9  n_splits =  2  result =  0.765625
#
# Pregnancies BloodPressure SkinThickness Age
# k =  9  n_splits =  3  result =  0.7630208333333334
#
# Pregnancies BloodPressure Insulin BMI
# k =  9  n_splits =  2  result =  0.7486979166666667
#
# Pregnancies BloodPressure Insulin DiabetesPedigreeFunction
# k =  8  n_splits =  3  result =  0.7760416666666666
#
# Pregnancies BloodPressure Insulin Age
# k =  9  n_splits =  4  result =  0.7486979166666666
#
# Pregnancies BloodPressure BMI DiabetesPedigreeFunction
# k =  6  n_splits =  2  result =  0.7552083333333334
#
# Pregnancies BloodPressure BMI Age
# k =  8  n_splits =  2  result =  0.7421875
#
# Pregnancies BloodPressure DiabetesPedigreeFunction Age
# k =  8  n_splits =  9  result =  0.747454020367837
#
# Pregnancies SkinThickness Insulin BMI
# k =  9  n_splits =  3  result =  0.7604166666666666
#
# Pregnancies SkinThickness Insulin DiabetesPedigreeFunction
# k =  9  n_splits =  5  result =  0.7604787369493251
#
# Pregnancies SkinThickness Insulin Age
# k =  6  n_splits =  2  result =  0.75
#
# Pregnancies SkinThickness BMI DiabetesPedigreeFunction
# k =  3  n_splits =  2  result =  0.7526041666666667
#
# Pregnancies SkinThickness BMI Age
# k =  8  n_splits =  3  result =  0.7408854166666666
#
# Pregnancies SkinThickness DiabetesPedigreeFunction Age
# k =  9  n_splits =  2  result =  0.7565104166666666
#
# Pregnancies Insulin BMI DiabetesPedigreeFunction
# k =  6  n_splits =  7  result =  0.7487668295007744
#
# Pregnancies Insulin BMI Age
# k =  6  n_splits =  2  result =  0.7369791666666666
#
# Pregnancies Insulin DiabetesPedigreeFunction Age
# k =  9  n_splits =  2  result =  0.7486979166666667
#
# Pregnancies BMI DiabetesPedigreeFunction Age
# k =  7  n_splits =  2  result =  0.7421875
#
# Glucose BloodPressure SkinThickness Insulin
# k =  9  n_splits =  4  result =  0.7083333333333334
#
# Glucose BloodPressure SkinThickness BMI
# k =  7  n_splits =  6  result =  0.6809895833333334
#
# Glucose BloodPressure SkinThickness DiabetesPedigreeFunction
# k =  7  n_splits =  7  result =  0.7095079232693912
#
# Glucose BloodPressure SkinThickness Age
# k =  6  n_splits =  2  result =  0.6940104166666666
#
# Glucose BloodPressure Insulin BMI
# k =  8  n_splits =  2  result =  0.6653645833333333
#
# Glucose BloodPressure Insulin DiabetesPedigreeFunction
# k =  7  n_splits =  4  result =  0.6979166666666666
#
# Glucose BloodPressure Insulin Age
# k =  8  n_splits =  6  result =  0.6731770833333334
#
# Glucose BloodPressure BMI DiabetesPedigreeFunction
# k =  3  n_splits =  9  result =  0.6964888280893754
#
# Glucose BloodPressure BMI Age
# k =  8  n_splits =  2  result =  0.6692708333333333
#
# Glucose BloodPressure DiabetesPedigreeFunction Age
# k =  4  n_splits =  3  result =  0.67578125
#
# Glucose SkinThickness Insulin BMI
# k =  7  n_splits =  2  result =  0.6731770833333334
#
# Glucose SkinThickness Insulin DiabetesPedigreeFunction
# k =  9  n_splits =  4  result =  0.6875
#
# Glucose SkinThickness Insulin Age
# k =  8  n_splits =  3  result =  0.6692708333333334
#
# Glucose SkinThickness BMI DiabetesPedigreeFunction
# k =  9  n_splits =  3  result =  0.671875
#
# Glucose SkinThickness BMI Age
# k =  8  n_splits =  3  result =  0.6653645833333334
#
# Glucose SkinThickness DiabetesPedigreeFunction Age
# k =  7  n_splits =  2  result =  0.6653645833333333
#
# Glucose Insulin BMI DiabetesPedigreeFunction
# k =  8  n_splits =  8  result =  0.65625
#
# Glucose Insulin BMI Age
# k =  8  n_splits =  3  result =  0.65625
#
# Glucose Insulin DiabetesPedigreeFunction Age
# k =  9  n_splits =  3  result =  0.64453125
#
# Glucose BMI DiabetesPedigreeFunction Age
# k =  2  n_splits =  9  result =  0.6602675178598572
#
# BloodPressure SkinThickness Insulin BMI
# k =  9  n_splits =  4  result =  0.7565104166666666
#
# BloodPressure SkinThickness Insulin DiabetesPedigreeFunction
# k =  7  n_splits =  4  result =  0.76953125
#
# BloodPressure SkinThickness Insulin Age
# k =  5  n_splits =  2  result =  0.7578125
#
# BloodPressure SkinThickness BMI DiabetesPedigreeFunction
# k =  5  n_splits =  8  result =  0.7526041666666667
#
# BloodPressure SkinThickness BMI Age
# k =  8  n_splits =  4  result =  0.7434895833333334
#
# BloodPressure SkinThickness DiabetesPedigreeFunction Age
# k =  8  n_splits =  9  result =  0.7525915792673659
#
# BloodPressure Insulin BMI DiabetesPedigreeFunction
# k =  9  n_splits =  4  result =  0.7395833333333334
#
# BloodPressure Insulin BMI Age
# k =  8  n_splits =  4  result =  0.7421875
#
# BloodPressure Insulin DiabetesPedigreeFunction Age
# k =  8  n_splits =  3  result =  0.7473958333333334
#
# BloodPressure BMI DiabetesPedigreeFunction Age
# k =  8  n_splits =  4  result =  0.71484375
#
# SkinThickness Insulin BMI DiabetesPedigreeFunction
# k =  9  n_splits =  7  result =  0.7487191707375194
#
# SkinThickness Insulin BMI Age
# k =  9  n_splits =  6  result =  0.7278645833333334
#
# SkinThickness Insulin DiabetesPedigreeFunction Age
# k =  8  n_splits =  9  result =  0.7526523787809698
#
# SkinThickness BMI DiabetesPedigreeFunction Age
# k =  9  n_splits =  8  result =  0.73828125
#
# Insulin BMI DiabetesPedigreeFunction Age
# k =  8  n_splits =  7  result =  0.7227213153818658

# %%
# MinMaxScaler
# Removal of 5 features
features = list(df1.columns)
features = [features[:-1]]

scaler = MinMaxScaler()
for feature in features:
    df1[feature] = scaler.fit_transform(df1[feature])

l = []
for i in range(0,8):
    for j in range(i+1,8):
        for k in range(j+1,8):
            for m in range(k+1,8):
                for o in range(m+1,8):
                    l.append([i,j,k,m,o])


                    
#Create X and y variable
for i in l: 
    print(features[0][i[0]],features[0][i[1]],features[0][i[2]],features[0][i[3]],features[0][i[4]])
    X = df1.drop(columns=['Outcome', features[0][i[0]],features[0][i[1]],features[0][i[2]],features[0][i[3]],features[0][i[4]]])
    y = df1['Outcome']
    func1()
# Out:
# Pregnancies Glucose BloodPressure SkinThickness Insulin
# k =  4  n_splits =  2  result =  0.7174479166666666
#
# Pregnancies Glucose BloodPressure SkinThickness BMI
# k =  9  n_splits =  3  result =  0.7135416666666666
#
# Pregnancies Glucose BloodPressure SkinThickness DiabetesPedigreeFunction
# k =  9  n_splits =  5  result =  0.7134368899074781
#
# Pregnancies Glucose BloodPressure SkinThickness Age
# k =  8  n_splits =  2  result =  0.7083333333333334
#
# Pregnancies Glucose BloodPressure Insulin BMI
# k =  9  n_splits =  2  result =  0.67578125
#
# Pregnancies Glucose BloodPressure Insulin DiabetesPedigreeFunction
# k =  8  n_splits =  3  result =  0.68359375
#
# Pregnancies Glucose BloodPressure Insulin Age
# k =  9  n_splits =  3  result =  0.6796875
#
# Pregnancies Glucose BloodPressure BMI DiabetesPedigreeFunction
# k =  7  n_splits =  5  result =  0.6744758509464391
#
# Pregnancies Glucose BloodPressure BMI Age
# k =  5  n_splits =  8  result =  0.671875
#
# Pregnancies Glucose BloodPressure DiabetesPedigreeFunction Age
# k =  2  n_splits =  4  result =  0.69921875
#
# Pregnancies Glucose SkinThickness Insulin BMI
# k =  6  n_splits =  3  result =  0.6705729166666666
#
# Pregnancies Glucose SkinThickness Insulin DiabetesPedigreeFunction
# k =  9  n_splits =  2  result =  0.6744791666666667
#
# Pregnancies Glucose SkinThickness Insulin Age
# k =  2  n_splits =  5  result =  0.6731177319412613
#
# Pregnancies Glucose SkinThickness BMI DiabetesPedigreeFunction
# k =  9  n_splits =  9  result =  0.677124183006536
#
# Pregnancies Glucose SkinThickness BMI Age
# k =  9  n_splits =  2  result =  0.6549479166666666
#
# Pregnancies Glucose SkinThickness DiabetesPedigreeFunction Age
# k =  9  n_splits =  3  result =  0.66015625
#
# Pregnancies Glucose Insulin BMI DiabetesPedigreeFunction
# k =  8  n_splits =  4  result =  0.6471354166666667
#
# Pregnancies Glucose Insulin BMI Age
# k =  8  n_splits =  5  result =  0.6536541889483065
#
# Pregnancies Glucose Insulin DiabetesPedigreeFunction Age
# k =  6  n_splits =  7  result =  0.652317407363279
#
# Pregnancies Glucose BMI DiabetesPedigreeFunction Age
# k =  9  n_splits =  9  result =  0.6472108223134215
#
# Pregnancies BloodPressure SkinThickness Insulin BMI
# k =  9  n_splits =  2  result =  0.76953125
#
# Pregnancies BloodPressure SkinThickness Insulin DiabetesPedigreeFunction
# k =  9  n_splits =  2  result =  0.7643229166666666
#
# Pregnancies BloodPressure SkinThickness Insulin Age
# k =  9  n_splits =  2  result =  0.74609375
#
# Pregnancies BloodPressure SkinThickness BMI DiabetesPedigreeFunction
# k =  7  n_splits =  2  result =  0.7591145833333334
#
# Pregnancies BloodPressure SkinThickness BMI Age
# k =  8  n_splits =  7  result =  0.7423209817705231
#
# Pregnancies BloodPressure SkinThickness DiabetesPedigreeFunction Age
# k =  9  n_splits =  3  result =  0.7447916666666666
#
# Pregnancies BloodPressure Insulin BMI DiabetesPedigreeFunction
# k =  8  n_splits =  3  result =  0.7447916666666666
#
# Pregnancies BloodPressure Insulin BMI Age
# k =  9  n_splits =  4  result =  0.7395833333333334
#
# Pregnancies BloodPressure Insulin DiabetesPedigreeFunction Age
# k =  9  n_splits =  3  result =  0.7447916666666666
#
# Pregnancies BloodPressure BMI DiabetesPedigreeFunction Age
# k =  7  n_splits =  5  result =  0.7291995586113234
#
# Pregnancies SkinThickness Insulin BMI DiabetesPedigreeFunction
# k =  7  n_splits =  2  result =  0.7552083333333333
#
# Pregnancies SkinThickness Insulin BMI Age
# k =  8  n_splits =  4  result =  0.7421875
#
# Pregnancies SkinThickness Insulin DiabetesPedigreeFunction Age
# k =  9  n_splits =  7  result =  0.7513046586441083
#
# Pregnancies SkinThickness BMI DiabetesPedigreeFunction Age
# k =  7  n_splits =  2  result =  0.7526041666666667
#
# Pregnancies Insulin BMI DiabetesPedigreeFunction Age
# k =  8  n_splits =  9  result =  0.748609211126311
#
# Glucose BloodPressure SkinThickness Insulin BMI
# k =  6  n_splits =  8  result =  0.671875
#
# Glucose BloodPressure SkinThickness Insulin DiabetesPedigreeFunction
# k =  9  n_splits =  4  result =  0.7109375
#
# Glucose BloodPressure SkinThickness Insulin Age
# k =  2  n_splits =  9  result =  0.6887368901048792
#
# Glucose BloodPressure SkinThickness BMI DiabetesPedigreeFunction
# k =  6  n_splits =  6  result =  0.6822916666666666
#
# Glucose BloodPressure SkinThickness BMI Age
# k =  4  n_splits =  2  result =  0.6731770833333334
#
# Glucose BloodPressure SkinThickness DiabetesPedigreeFunction Age
# k =  8  n_splits =  2  result =  0.6940104166666667
#
# Glucose BloodPressure Insulin BMI DiabetesPedigreeFunction
# k =  6  n_splits =  8  result =  0.6640625
#
# Glucose BloodPressure Insulin BMI Age
# k =  8  n_splits =  3  result =  0.6549479166666666
#
# Glucose BloodPressure Insulin DiabetesPedigreeFunction Age
# k =  4  n_splits =  7  result =  0.6732038603598236
#
# Glucose BloodPressure BMI DiabetesPedigreeFunction Age
# k =  8  n_splits =  9  result =  0.6730810153518771
#
# Glucose SkinThickness Insulin BMI DiabetesPedigreeFunction
# k =  6  n_splits =  7  result =  0.6588585726200404
#
# Glucose SkinThickness Insulin BMI Age
# k =  8  n_splits =  4  result =  0.6666666666666667
#
# Glucose SkinThickness Insulin DiabetesPedigreeFunction Age
# k =  6  n_splits =  3  result =  0.6549479166666666
#
# Glucose SkinThickness BMI DiabetesPedigreeFunction Age
# k =  6  n_splits =  7  result =  0.6692958417729059
#
# Glucose Insulin BMI DiabetesPedigreeFunction Age
# k =  4  n_splits =  6  result =  0.65234375
#
# BloodPressure SkinThickness Insulin BMI DiabetesPedigreeFunction
# k =  5  n_splits =  4  result =  0.7643229166666666
#
# BloodPressure SkinThickness Insulin BMI Age
# k =  8  n_splits =  9  result =  0.7565587475300197
#
# BloodPressure SkinThickness Insulin DiabetesPedigreeFunction Age
# k =  9  n_splits =  3  result =  0.7513020833333334
#
# BloodPressure SkinThickness BMI DiabetesPedigreeFunction Age
# k =  6  n_splits =  9  result =  0.7173734610123119
#
# BloodPressure Insulin BMI DiabetesPedigreeFunction Age
# k =  8  n_splits =  6  result =  0.7278645833333334
#
# SkinThickness Insulin BMI DiabetesPedigreeFunction Age
# k =  9  n_splits =  6  result =  0.7317708333333334

# %%
# MinMaxScaler
# Removal of 6 features
features = list(df1.columns)
features = [features[:-1]]

scaler = MinMaxScaler()
for feature in features:
    df1[feature] = scaler.fit_transform(df1[feature])

l = []
for i in range(0,8):
    for j in range(i+1,8):
        for k in range(j+1,8):
            for m in range(k+1,8):
                for o in range(m+1,8):
                    for p in range(o+1,8):
                        l.append([i,j,k,m,o,p])


                    
#Create X and y variable
for i in l: 
    print(features[0][i[0]],features[0][i[1]],features[0][i[2]],features[0][i[3]],features[0][i[4]],features[0][i[5]])
    X = df1.drop(columns=['Outcome', features[0][i[0]],features[0][i[1]],features[0][i[2]],features[0][i[3]],features[0][i[4]],features[0][i[5]]])
    y = df1['Outcome']
    func1()
# Out:
# Pregnancies Glucose BloodPressure SkinThickness Insulin BMI
# k =  9  n_splits =  3  result =  0.67578125
#
# Pregnancies Glucose BloodPressure SkinThickness Insulin DiabetesPedigreeFunction
# k =  9  n_splits =  3  result =  0.6979166666666666
#
# Pregnancies Glucose BloodPressure SkinThickness Insulin Age
# k =  8  n_splits =  9  result =  0.6952120383036937
#
# Pregnancies Glucose BloodPressure SkinThickness BMI DiabetesPedigreeFunction
# k =  9  n_splits =  5  result =  0.6914353620235973
#
# Pregnancies Glucose BloodPressure SkinThickness BMI Age
# k =  9  n_splits =  4  result =  0.6705729166666666
#
# Pregnancies Glucose BloodPressure SkinThickness DiabetesPedigreeFunction Age
# k =  4  n_splits =  6  result =  0.7018229166666666
#
# Pregnancies Glucose BloodPressure Insulin BMI DiabetesPedigreeFunction
# k =  9  n_splits =  3  result =  0.6484375
#
# Pregnancies Glucose BloodPressure Insulin BMI Age
# k =  2  n_splits =  5  result =  0.6562176385705797
#
# Pregnancies Glucose BloodPressure Insulin DiabetesPedigreeFunction Age
# k =  4  n_splits =  5  result =  0.6719208895679485
#
# Pregnancies Glucose BloodPressure BMI DiabetesPedigreeFunction Age
# k =  9  n_splits =  4  result =  0.6744791666666667
#
# Pregnancies Glucose SkinThickness Insulin BMI DiabetesPedigreeFunction
# k =  9  n_splits =  2  result =  0.6549479166666666
#
# Pregnancies Glucose SkinThickness Insulin BMI Age
# k =  8  n_splits =  2  result =  0.6458333333333334
#
# Pregnancies Glucose SkinThickness Insulin DiabetesPedigreeFunction Age
# k =  2  n_splits =  5  result =  0.6536372124607419
#
# Pregnancies Glucose SkinThickness BMI DiabetesPedigreeFunction Age
# k =  6  n_splits =  2  result =  0.6536458333333333
#
# Pregnancies Glucose Insulin BMI DiabetesPedigreeFunction Age
# k =  2  n_splits =  7  result =  0.6328130585011319
#
# Pregnancies BloodPressure SkinThickness Insulin BMI DiabetesPedigreeFunction
# k =  8  n_splits =  3  result =  0.7526041666666666
#
# Pregnancies BloodPressure SkinThickness Insulin BMI Age
# k =  9  n_splits =  2  result =  0.7421875
#
# Pregnancies BloodPressure SkinThickness Insulin DiabetesPedigreeFunction Age
# k =  8  n_splits =  3  result =  0.7604166666666666
#
# Pregnancies BloodPressure SkinThickness BMI DiabetesPedigreeFunction Age
# k =  8  n_splits =  8  result =  0.71875
#
# Pregnancies BloodPressure Insulin BMI DiabetesPedigreeFunction Age
# k =  5  n_splits =  7  result =  0.7461455975217444
#
# Pregnancies SkinThickness Insulin BMI DiabetesPedigreeFunction Age
# k =  8  n_splits =  6  result =  0.7513020833333334
#
# Glucose BloodPressure SkinThickness Insulin BMI DiabetesPedigreeFunction
# k =  9  n_splits =  4  result =  0.6757812500000001
#
# Glucose BloodPressure SkinThickness Insulin BMI Age
# k =  8  n_splits =  2  result =  0.66015625
#
# Glucose BloodPressure SkinThickness Insulin DiabetesPedigreeFunction Age
# k =  6  n_splits =  9  result =  0.6849673202614379
#
# Glucose BloodPressure SkinThickness BMI DiabetesPedigreeFunction Age
# k =  2  n_splits =  7  result =  0.687489574645538
#
# Glucose BloodPressure Insulin BMI DiabetesPedigreeFunction Age
# k =  8  n_splits =  7  result =  0.6613964017633743
#
# Glucose SkinThickness Insulin BMI DiabetesPedigreeFunction Age
# k =  8  n_splits =  2  result =  0.6536458333333333
#
# BloodPressure SkinThickness Insulin BMI DiabetesPedigreeFunction Age
# k =  8  n_splits =  2  result =  0.7252604166666667
